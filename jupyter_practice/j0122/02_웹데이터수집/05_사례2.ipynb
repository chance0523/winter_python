# %% [markdown]
# # 네이버 140자평 데이터 수집
#
# 상영장 예매순위 top 15 영화에 대한 140자평 데이터를 수집한다.
#
# 가져오고자 하는 요소가 1개가 아니기 때문에 각각 요소를 구분할 수 있는 값을 먼저 추출하고 그 값을 이용해 각각의 영화를 모두 요청해서 데이터를 가져온다.

# %%
import bs4
import requests
import time
import pandas
import os

# %%
# 접속할 페이지의 주소
# 예매순 첫번째 영화의 주소 (나중에 바꿔주기!)
site = 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=176306'

# %%
# 요청
response = requests.get(site)
response
# Out:
# <Response [200]>

# %%
# bs4 객체를 생성
soup = bs4.BeautifulSoup(response.text,'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="no" http-equiv="imagetoolbar"/>
# <title>남산의 부장들 : 네이버 영화</title>
# <meta content="https://ssl.pstatic.net/imgmovie/today/naverme/naverme_profile.jpg" property="me2:image"/>
# <meta content="네이버영화 남산의 부장들" property="me2:post_tag"/>
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="남산의 부장들" property="me2:category2"/>
# <meta content="남산의 부장들" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/bi/mi/basic.nhn?code=176306" property="og:url"/>
# <meta content="https://movie-phinf.pstatic.net/20200103_41/1578032244761ejKMX_JPEG/movie_image.jpg?type=m665_443_2" property="og:image"/>
# <meta content="1979년 10월 26일, 중앙정보부장 김규평(이병헌)이 대한민국 대통령을 암살한다.이 사건의 40일전, 미국..." property="og:description"/>
# <meta content="https://ssl.pstatic.net/imgmovie/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# <meta content="네이버 영화" property="og:article:author"/>
# <meta content="https://movie.naver.com/" property="og:article:author:url"/>
# <link href="https://ssl.pstatic.net/static/m/movie/icons/naver_movie_favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/css/deploy/movie.all.css?20200113160235" rel="stylesheet" type="text/css"/>
# <script src="/js/deploy/movie.all.js?20200113160235" type="text/javascript"></script>
# </head>
# <body>
# <div class="basic" id="wrap">
# <!-- GNB -->
# <script type="text/javascript">
# function delayed_submit(object) {
# 	if (navigator.userAgent.indexOf('MSIE') == -1) {
# 		var b = c = new Date();
#       	while ((b.getTime() - c.getTime()) < 100) {
# 			b = new Date();
#       	}
# 	}
# }
# </script>
# <script type="text/javascript">
# 	var gnb_service = "movie";
# 	var gnb_logout = "http://movie.naver.com/movie/bi/mi/basic.nhn%3Fcode%3D176306";
# 	var gnb_template = "gnb_utf8";
# 	var gnb_brightness=3;
# 	var gnb_response = true;
#
# 	jindo.$Fn(function(){
# 		getGNB();
# 	}).attach(window, "load");
#
# 	jindo.$Fn(function(oEvent){ var welSource = jindo.$Element(oEvent.element);
# 			if (!welSource.isChildOf(jindo.$Element("gnb"))) {
# 				gnbAllLayerClose();
# 			}
# 	}).attach(document, 'click');
# </script>
# <!-- skip navigation -->
# <div id="u_skip">
# <a href="#header" onclick="document.getElementById('header').tabIndex=-1;document.getElementById('header').focus();return false;"><span>메인 메뉴로 바로가기</span></a>
# <a href="#content" id="gnb_goContent" onclick="document.getElementById('content').tabIndex=-1;document.getElementById('content').focus();return false;"><span>본문으로 바로가기</span></a>
# </div>
# <!-- //skip navigation -->
# <div class="gnb_container">
# <div class="gnb_content">
# <div class="gnb_box">
# <div class="gnb_wrap">
# <div id="gnb">
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn" type="text/javascript"></script>
# </div>
# </div>
# <!-- 검색창 -->
# <form action="/movie/search/result.nhn" id="jSearchForm" method="get" style="margin:0;display:none;">
# <input maxlength="100" name="query" title="영화검색" type="text"/>
# <input name="section" type="hidden" value="all"/>
# <input name="ie" type="hidden" value="utf8"/>
# </form>
# <fieldset class="srch_area" id="jSearchArea">
# <legend><span class="blind">영화검색 영역</span></legend>
# <div class="srch_field_on _view">
# <span class="ipt_srch">
# <label for="ipt_tx_srch" id="search_placeholder">영화검색</label>
# <input accesskey="s" autocomplete="off" class="ipt_tx_srch" id="ipt_tx_srch" maxlength="100" name="query" style="ime-mode:active;" type="text"/>
# <span class="align"></span>
# <span class="auto_tx"><a href="#" title="자동완성 펼치기"><img alt="자동완성 펼치기" height="4" src="https://ssl.pstatic.net/static/movie/2012/06/srch_arrow_down.gif" title="자동완성 펼치기" width="7"/></a></span>
# </span>
# <button class="btn_srch" onclick="clickcr(this,'GNB.search','','',event); delayed_submit(this);" title="검색" type="submit"><span class="blind">검색</span></button>
# <!-- 자동 완성 영역임 #autocomplate_template-->
# </div>
# </fieldset>
# <!-- //검색창 -->
# </div>
# </div>
# </div>
# <!-- //GNB -->
# <!-- header -->
# <div id="header">
# <a class="blind" href="#content" title="본문으로 이동">본문 바로가기</a>
# <h1 class="svc_name">
# <a class="ci_logo" href="http://www.naver.com/" id="lnb_gonaver" title="naver로 바로가기"><img alt="NAVER" height="13" src="https://ssl.pstatic.net/static/movie/2013/07/logo_ci.png" width="62"/></a><!-- N=a:LNB.naver -->
# <a class="svc_logo" href="/" title="영화서비스홈으로 바로가기"><img alt="영화" height="19" src="https://ssl.pstatic.net/static/movie/2012/06/logo_svc.png" width="34"/></a><!-- N=a:LNB.movie -->
# </h1>
# <div class="scrollbar scrollbar-noscript" id="scrollbar">
# <div class="scrollbar-box">
# <div class="scrollbar-content">
# <div class="in_scroll">
# <ul class="navi">
# <li>
# <a class="menu01" href="/" title="영화홈"><strong>영화홈</strong></a><!-- N=a:LNB.home -->
# </li>
# <li>
# <a class="menu02_on" href="/movie/running/current.nhn" title="상영작·예정작"><strong>상영작·예정작</strong></a><!-- N=a:LNB.movies -->
# <ul class="navi_sub" id="navi_movie" style="display:none">
# <li><a class="sub2_1_on" href="/movie/running/current.nhn" title="현재 상영영화"><em>현재 상영영화</em></a><!-- N=a:LNB.now --></li>
# <li><a class="sub2_2" href="/movie/running/premovie.nhn" title="개봉 예정영화"><em>개봉 예정영화</em></a><!-- N=a:LNB.soon --></li>
# <li><a class="sub2_4" href="/movie/running/movieclip.nhn" title="예고편"><em>예고편</em></a><!-- N=a:LNB.tailer --></li>
# </ul>
# </li>
# <li>
# <a class="menu03" href="/movie/sdb/rank/rmovie.nhn" title="영화랭킹"><strong>영화랭킹</strong></a><!-- N=a:LNB.db -->
# </li>
# <li>
# <a class="menu05" href="/movie/bi/mi/reserve.nhn" title="예매"><strong>예매</strong></a><!-- N=a:LNB.ticket -->
# </li>
# <li>
# <a class="menu07" href="/movie/point/af/list.nhn" title="평점&amp;middot리뷰"><strong>평점&amp;middot리뷰</strong></a><!-- N=a:LNB.comm -->
# </li>
# <li>
# <a class="menu08" href="https://serieson.naver.com/movie/home.nhn" target="_blank" title="다운로드"><strong>다운로드</strong></a><!-- N=a:LNB.download -->
# </li>
# <li class="nav_indi">
# <a href="http://tv.naver.com/indiecinema" target="_blank" title="인디극장 UP"><strong>인디극장 UP</strong></a><!-- N=a:LNB.indie -->
# </li>
# </ul>
# <!-- [D] view 모드 전환간 클래스는 _on,_off / 비활성화는 _disabled -->
# <div class="lnb_etc" id="viewmode-option-area">
# <div class="info_view">
# <a class="_info-anchor btn_view_md" href="#"><em>보기옵션</em></a>
# <div class="ly_info_view" id="_viewmode-option-info-layer" style="display:none">
# <span></span>
# 										브라우저의 해상도에 따라 기본 혹은 넓게보기가 가능합니다. 넓게보기는 가로해상도 1872픽셀 이상에서만 동작합니다.
# 									</div>
# </div>
# <div class="view_mode">
# <a class="_basic-btn normal_on" href="#" title=""><em>기본보기</em></a>
# <a class="_wide-btn wide_off" href="#" title=""><em>넓게보기</em></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="scrollbar-v">
# <div class="scrollbar-button-up"></div>
# <div class="scrollbar-track">
# <div class="scrollbar-thumb"></div>
# </div>
# <div class="scrollbar-button-down"></div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# 	if ("현재 상영영화" == "상영작·예정작"
# 			|| "현재 상영영화" == "현재 상영영화"
# 			|| "현재 상영영화" == "개봉 예정영화"
# 			|| "현재 상영영화" == "TV 방영영화"
# 			|| "현재 상영영화" == "예고편") {
# 		jindo.$Element("navi_movie").show();
# 	}
# 	</script>
# <!-- //header -->
# <!-- container -->
# <div id="container">
# <!-- 프로모션 레이어 -->
# <div class="ly_promo" id="thumb_promotion_layer"><h3>원하시는 영화를 선택해보세요.</h3>
# 			화제가 되고 있는 최신영화 정보를 한 눈에 확인하실 수 있습니다.
# 			<a class="btn_clse" href="#" id="thumb_promotion_layer_close" title="닫기">닫기</a>
# </div>
# <!-- 상단 현재 상영작 썸네일 리스트 -->
# <div class="spot">
# <div class="top_list" id="_TopArea">
# <div class="first_mv_list current_mv_list _mv_default_list">
# <button class="_prev-btn thumb_prev" onclick="clickcr(this,'rnk.prev','','',event);" type="button"><em>이전</em></button>
# <a class="h_current_mv" href="/movie/running/current.nhn?order=reserve" id="first_mv_list_link"><h2><strong class="blind">상영작 예매순위</strong></h2></a><!-- N=a:rnk.ntitle -->
# <div class="top_poster_area">
# <ul class="top_thumb_lst">
# <li class="on" data-title="남산의 부장들"><a href="/movie/bi/mi/basic.nhn?code=176306"><img alt="남산의 부장들" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200103_41/1578032244761ejKMX_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="히트맨"><a href="/movie/bi/mi/basic.nhn?code=185838"><img alt="히트맨" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200122_181/15796574636309Fux2_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="미스터 주: 사라진 VIP"><a href="/movie/bi/mi/basic.nhn?code=177509"><img alt="미스터 주: 사라진 VIP" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200122_11/15796766202282GrU2_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="스파이 지니어스"><a href="/movie/bi/mi/basic.nhn?code=172780"><img alt="스파이 지니어스" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200120_187/157948230962440pnt_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="해치지않아"><a href="/movie/bi/mi/basic.nhn?code=180025"><img alt="해치지않아" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200115_223/1579061805057fDTGd_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="닥터 두리틀"><a href="/movie/bi/mi/basic.nhn?code=159866"><img alt="닥터 두리틀" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191226_207/1577328208589oxfYb_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="타오르는 여인의 초상"><a href="/movie/bi/mi/basic.nhn?code=185282"><img alt="타오르는 여인의 초상" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191220_49/1576828214038i4ukE_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="나쁜 녀석들 : 포에버"><a href="/movie/bi/mi/basic.nhn?code=76960"><img alt="나쁜 녀석들 : 포에버" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200107_50/1578361868623t7Qp6_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="하이큐!! 땅 VS 하늘"><a href="/movie/bi/mi/basic.nhn?code=191431"><img alt="하이큐!! 땅 VS 하늘" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200117_26/1579249737548VjD7N_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="오즈의 마법사: 요술구두와 말하는 책"><a href="/movie/bi/mi/basic.nhn?code=190336"><img alt="오즈의 마법사: 요술구두와 말하는 책" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191219_69/15767213057872nskQ_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="백두산"><a href="/movie/bi/mi/basic.nhn?code=187940"><img alt="백두산" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191219_263/15767415637757HPgg_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="스타워즈: 라이즈 오브 스카이워커"><a href="/movie/bi/mi/basic.nhn?code=144694"><img alt="스타워즈: 라이즈 오브 스카이워커" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200108_148/1578462346140MWVbW_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="겨울왕국 2"><a href="/movie/bi/mi/basic.nhn?code=136873"><img alt="겨울왕국 2" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191121_221/1574298335357mqgLk_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="사마에게"><a href="/movie/bi/mi/basic.nhn?code=184571"><img alt="사마에게" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191224_60/1577155153773iLYXG_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="파바로티"><a href="/movie/bi/mi/basic.nhn?code=185357"><img alt="파바로티" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191202_163/1575249627261QLaXz_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# </ul>
# </div>
# <button class="_next-btn thumb_next" onclick="clickcr(this,'rnk.next','','',event);" type="button"><em>다음</em></button>
# </div>
# <div class="second_mv_list expected_mv_list _mv_default_list">
# <button class="_prev-btn thumb_prev" onclick="clickcr(this,'rnk.prev','','',event);" type="button"><em>이전</em></button>
# <a class="h_expected_mv" href="/movie/running/premovie.nhn" id="second_mv_list_link"><h2><strong class="blind">예정작 개봉일순</strong></h2></a><!-- N=a:rnk.stitle -->
# <div class="top_poster_area">
# <ol class="top_thumb_lst">
# <li data-title="인셉션"><a href="/movie/bi/mi/basic.nhn?code=52515"><img alt="인셉션" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200114_147/1578963901287frmdl_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="나이트 헌터"><a href="/movie/bi/mi/basic.nhn?code=162266"><img alt="나이트 헌터" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200113_6/15789031105846XFQG_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="목격자 : 눈이 없는 아이"><a href="/movie/bi/mi/basic.nhn?code=148304"><img alt="목격자 : 눈이 없는 아이" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200117_213/1579246893626IKoQE_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="성혜의 나라"><a href="/movie/bi/mi/basic.nhn?code=174294"><img alt="성혜의 나라" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200117_234/1579244142345CI1m5_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="카잔자키스"><a href="/movie/bi/mi/basic.nhn?code=181276"><img alt="카잔자키스" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191230_129/1577682525473H2GK5_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="공기인형"><a href="/movie/bi/mi/basic.nhn?code=52075"><img alt="공기인형" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200117_245/1579242819933PKRT4_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="잃어버린 세계를 찾아서"><a href="/movie/bi/mi/basic.nhn?code=181692"><img alt="잃어버린 세계를 찾아서" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200117_155/1579251870613UHFPs_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="프라이멀"><a href="/movie/bi/mi/basic.nhn?code=191435"><img alt="프라이멀" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200107_169/1578384561626hn8MG_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="핑크퐁 시네마 콘서트 : 우주대탐험"><a href="/movie/bi/mi/basic.nhn?code=190306"><img alt="핑크퐁 시네마 콘서트 : 우주대탐험" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200102_285/1577953298353zNup8_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="버즈 오브 프레이(할리 퀸의 황홀한 해방)"><a href="/movie/bi/mi/basic.nhn?code=187350"><img alt="버즈 오브 프레이(할리 퀸의 황홀한 해방)" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200121_188/1579574685635qE9iF_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="페인 앤 글로리"><a href="/movie/bi/mi/basic.nhn?code=185254"><img alt="페인 앤 글로리" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200117_284/1579222418406zjjde_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="조조 래빗"><a href="/movie/bi/mi/basic.nhn?code=187308"><img alt="조조 래빗" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200121_285/1579591964650C0yMw_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="더 프린세스 : 도둑맞은 공주"><a href="/movie/bi/mi/basic.nhn?code=178351"><img alt="더 프린세스 : 도둑맞은 공주" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200115_157/1579052036654ABHnf_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="클로젯"><a href="/movie/bi/mi/basic.nhn?code=181925"><img alt="클로젯" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200116_23/1579154974413LvtIf_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="극장판 미니특공대: 공룡왕 디노"><a href="/movie/bi/mi/basic.nhn?code=190325"><img alt="극장판 미니특공대: 공룡왕 디노" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200115_201/1579055961204pU2PH_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# </ol>
# </div>
# <button class="_next-btn thumb_next" onclick="clickcr(this,'rnk.next','','',event);" type="button"><em>다음</em></button>
# </div>
# <a class="open_lst _expand-btn" href="#"><em class="blind" id="expandButtonName">상영예매순위, 예정작 개봉일순 더보기</em></a><!-- N=a:rnk.open -->
# <div class="open_mv_list _expansion-wrap" style="display:none">
# <div class="current_open">
# <div class="open_title_area">
# <h2 class="h_current_open">상영작 예매순위</h2>
# <a class="open_more" href="/movie/running/current.nhn?order=reserve" title="더보기"><em>더보기</em></a><!-- N=a:rnk.nmore -->
# </div>
# <ul class="current_list">
# <li class="on"><a href="/movie/bi/mi/basic.nhn?code=176306" title="남산의 부장들"><img alt="남산의 부장들" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200103_41/1578032244761ejKMX_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=185838" title="히트맨"><img alt="히트맨" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200122_181/15796574636309Fux2_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=177509" title="미스터 주: 사라진 VIP"><img alt="미스터 주: 사라진 VIP" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200122_11/15796766202282GrU2_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=172780" title="스파이 지니어스"><img alt="스파이 지니어스" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200120_187/157948230962440pnt_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=180025" title="해치지않아"><img alt="해치지않아" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200115_223/1579061805057fDTGd_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=159866" title="닥터 두리틀"><img alt="닥터 두리틀" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191226_207/1577328208589oxfYb_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=185282" title="타오르는 여인의 초상"><img alt="타오르는 여인의 초상" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191220_49/1576828214038i4ukE_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=76960" title="나쁜 녀석들 : 포에버"><img alt="나쁜 녀석들 : 포에버" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200107_50/1578361868623t7Qp6_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=191431" title="하이큐!! 땅 VS 하늘"><img alt="하이큐!! 땅 VS 하늘" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200117_26/1579249737548VjD7N_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=190336" title="오즈의 마법사: 요술구두와 말하는 책"><img alt="오즈의 마법사: 요술구두와 말하는 책" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191219_69/15767213057872nskQ_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=187940" title="백두산"><img alt="백두산" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191219_263/15767415637757HPgg_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=144694" title="스타워즈: 라이즈 오브 스카이워커"><img alt="스타워즈: 라이즈 오브 스카이워커" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200108_148/1578462346140MWVbW_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=136873" title="겨울왕국 2"><img alt="겨울왕국 2" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191121_221/1574298335357mqgLk_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=184571" title="사마에게"><img alt="사마에게" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191224_60/1577155153773iLYXG_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=185357" title="파바로티"><img alt="파바로티" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191202_163/1575249627261QLaXz_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=189000" title="나이브스 아웃"><img alt="나이브스 아웃" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191119_163/1574125979767APJb7_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=181381" title="천문: 하늘에 묻는다"><img alt="천문: 하늘에 묻는다" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191231_207/1577754153157vUcFn_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=181710" title="포드 V 페라리"><img alt="포드 V 페라리" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191204_91/15754257752042kHvB_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=29059" title="피아니스트의 전설"><img alt="피아니스트의 전설" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191220_107/1576822068106AEJns_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=189111" title="두 교황"><img alt="두 교황" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191016_196/1571192574061jEBrH_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# </ul>
# </div>
# <div class="expected_open">
# <div class="open_title_area">
# <h2 class="h_expected_open">예정작 개봉일순</h2>
# <a class="open_more" href="/movie/running/premovie.nhn" title="더보기"><em>더보기</em></a><!-- N=a:rnk.smore -->
# </div>
# <ol class="current_list">
# <li><a href="/movie/bi/mi/basic.nhn?code=52515" title="인셉션"><img alt="인셉션" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200114_147/1578963901287frmdl_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=162266" title="나이트 헌터"><img alt="나이트 헌터" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200113_6/15789031105846XFQG_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=148304" title="목격자 : 눈이 없는 아이"><img alt="목격자 : 눈이 없는 아이" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200117_213/1579246893626IKoQE_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=174294" title="성혜의 나라"><img alt="성혜의 나라" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200117_234/1579244142345CI1m5_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=181276" title="카잔자키스"><img alt="카잔자키스" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191230_129/1577682525473H2GK5_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=52075" title="공기인형"><img alt="공기인형" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200117_245/1579242819933PKRT4_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=181692" title="잃어버린 세계를 찾아서"><img alt="잃어버린 세계를 찾아서" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200117_155/1579251870613UHFPs_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=191435" title="프라이멀"><img alt="프라이멀" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200107_169/1578384561626hn8MG_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=190306" title="핑크퐁 시네마 콘서트 : 우주대탐험"><img alt="핑크퐁 시네마 콘서트 : 우주대탐험" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200102_285/1577953298353zNup8_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=187350" title="버즈 오브 프레이(할리 퀸의 황홀한 해방)"><img alt="버즈 오브 프레이(할리 퀸의 황홀한 해방)" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200121_188/1579574685635qE9iF_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=185254" title="페인 앤 글로리"><img alt="페인 앤 글로리" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200117_284/1579222418406zjjde_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=187308" title="조조 래빗"><img alt="조조 래빗" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200121_285/1579591964650C0yMw_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=178351" title="더 프린세스 : 도둑맞은 공주"><img alt="더 프린세스 : 도둑맞은 공주" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200115_157/1579052036654ABHnf_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=181925" title="클로젯"><img alt="클로젯" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200116_23/1579154974413LvtIf_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=190325" title="극장판 미니특공대: 공룡왕 디노"><img alt="극장판 미니특공대: 공룡왕 디노" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200115_201/1579055961204pU2PH_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=181287" title="이 멋진 세계에 축복을! 붉은 전설"><img alt="이 멋진 세계에 축복을! 붉은 전설" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200106_218/15782846353183YnK8_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=186613" title="작은 아씨들"><img alt="작은 아씨들" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200117_184/15792425940380AqI2_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=172816" title="수퍼 소닉"><img alt="수퍼 소닉" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200113_152/1578896572228Edueo_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=186821" title="정직한 후보"><img alt="정직한 후보" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200121_186/1579570188386BXMMG_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=179181" title="지푸라기라도 잡고 싶은 짐승들"><img alt="지푸라기라도 잡고 싶은 짐승들" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200107_66/1578362134872aLOCC_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# </ol>
# </div>
# </div>
# </div>
# </div>
# <!-- //상단 현재 상영작 썸네일 리스트 -->
# <script id="_TopAreaThumbnailExpander_tpl" type="text/template">
#             <div class="zoom_img" style="width:77px;height:110px;left:{=nLeft}px">
#                 <a href="{=sUrl}">
#                     <span class="img_mask">
#                             <p>{=sTitle}</p>
#                     </span>
#                     <img src="{=sImgSrc}" alt="" />
#                 </a>
#             </div>
#         </script>
# <script type="text/javascript">
# 			jindo.$Fn(
# 				function (we) {
# 					if (jindo.$('thumb_promotion_layer') != null) {
# 						jindo.$Fn(
# 							function(e) {
# 								jindo.$Element("thumb_promotion_layer").hide();
# 								jindo.$Cookie().set("NM_THUMB_PROMOTION_BLOCK", "Y", 1000);	//1000 days
# 							}
# 						).attach(jindo.$("thumb_promotion_layer_close"), "click").attach(jindo.$("_TopArea"), "click");
# 					}
# 				}
# 			).attach(document, 'domready');
#         </script>
# <!-- content -->
# <div id="content">
# <div class="article">
# <!-- 영화정보(wide) -->
# <div class="wide_info_area" style="display: none">
# <!-- 포스터 -->
# <div class="poster">
# <a href="#" onclick="javascript:common.iwopen('176306');clickcr(this,'ifo.img','','',event);return false;"><img alt="남산의 부장들" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110_1.png'" src="https://movie-phinf.pstatic.net/20200103_41/1578032244761ejKMX_JPEG/movie_image.jpg?type=m77_110_2"/><span>포스터 크게보기</span></a>
# </div>
# <!-- //포스터 -->
# <div class="mv_info">
# <h3 class="h_movie">
# <a href="./basic.nhn?code=176306">남산의 부장들</a><!-- N=a:ifo.title -->
# <a class="opening" href="/movie/running/current.nhn?order=reserve"><em>상영중</em></a><!-- N=a:ifo.nbtn -->
# <strong class="h_movie2" title="The Man Standing Next										, 					2018">The Man Standing Next
#
# 					,
# 					2018</strong>
# </h3>
# <div class="main_score">
# <div class="score">
# <div class="uio_ntz_btn see">
# <span class="ntz _actualPointHelpWide">
# <em class="blind">관람객 평점</em>
# <a class="help _actualPointHelpWide" href="#" id="actualPointHelpButtonWide">관람객 평점 도움말</a>
# </span>
# <div class="ly_ntz _actualPointHelpWide" id="actualPointHelpWide" style="display:none">
# <span></span>
# 							관람객 평점은 네이버영화에서<br/>예매하고 실제 관람 후 이용자들이<br/>작성한 평점입니다.
# 							<button class="btn_close _actualPointHelpWide" id="actualPointHelpCloseButtonWide" type="button"><em>닫기</em></button>
# </div>
# <div class="ly_count" id="actualPointCountWide" style="display:none">
# <span></span>
# 							참여 <em>135</em>명
# 						</div>
# </div>
# <a class="ntz_score" href="./point.nhn?code=176306&amp;onlyActualPointYn=Y#pointAfterTab" id="actualPointPersentWide">
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:85.1%">관람객 평점 8.51점</span></span><em class="num8">8</em><em class="dot">.</em><em class="num5">5</em><em class="num1">1</em>
# </div>
# </a><!-- N=a:ifo.mgrating -->
# </div>
# <div class="score">
# <div class="spc_score_area">
# <a class="spc" href="./point.nhn?code=176306#pointExpertTab">
# <span class="spc_score"><em class="blind">기자 · 평론가 평점</em></span>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:70.0%"></span></span><em class="num7">7</em><em class="dot">.</em><em class="num0">0</em><em class="num0">0</em>
# </div>
# </a><!-- N=a:ifo.crating -->
# </div>
# </div>
# <div class="score">
# <div class="uio_ntz_btn">
# <span class="ntz">
# <em class="blind">네티즌 평점</em><a class="help" href="#" id="pointHelpButtonWide" title="네티즌 평점 도움말 보기">네티즌 평점 도움말</a>
# </span>
# <div class="ly_ntz _pointHelpWide" id="pointHelpWide" style="display:none">
# <span></span>
#
#
#
# 								국내 개봉작입니다. 관람하신 영화에 대한<br/> 평점을 남겨주세요. 네티즌 평점 뿐 아니라 블<br/>로그 영화 리뷰작성 시 등록한 별점도 함께<br/> 반영됩니다.
#
#
# 						<button class="btn_close _pointHelpWide" id="pointHelpCloseButtonWide" type="button"><em>닫기</em></button>
# </div>
# <div class="ly_count" id="pointNetizenCountWide" style="display:none">
# <span></span>
# 						참여 <em>2,913</em>명
# 					</div>
# </div>
# <div class="star_score">
# <a href="./point.nhn?code=176306#pointAfterTab" id="pointNetizenPersentWide"><span class="st_off"><span class="st_on" style="width:74.8%"></span></span><em class="num7">7</em><em class="dot">.</em><em class="num4">4</em><em class="num8">8</em></a><!-- N=a:ifo..arating -->
# </div>
# </div>
# <div class="score" id="noPointWide">
# <div class="my_score_area">
# <!--[D] 내평점이 없는경우 화살표를 없애기 위해 class="my"가 빠진다 -->
# <a href="./point.nhn?code=176306#pointAfterTab">
# <span class="my_score"><em class="blind">내 평점</em></span>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:0%">0점</span></span>
# <span class="btn_write">등록</span>
# </div>
# </a>
# </div>
# </div>
# <div class="score" id="existPointWide" style="display : none">
# <div class="my_score_area">
# <a class="my" href="javascript:pointWide.toggleMyPoint();">
# <span class="my_score">
# <em class="blind">내 평점</em>
# </span>
# <div class="star_score" id="starPointWide">
# <span class="st_off"><span class="st_on" id="pointStarWide" style="width:0%"></span></span>
# </div>
# </a><!-- N=a:ifo.marating -->
# <div class="ly_my" id="myPointLayerWide" style="display:none">
# <span id="pointTextWide"></span><a class="btn_del" href="javascript:checkAlreadyPointAfterExist('wide', );" id="pointRemoveWide">삭제</a>
# <a class="btn_close" href="javascript:pointWide.toggleMyPoint();"><em>닫기</em></a>
# </div>
# </div>
# </div>
# </div>
# <p class="info_spec">
# <span>
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a>
# </span>
# <span>
# <a href="/movie/sdb/browsing/bmovie.nhn?nation=KR">한국</a>
# </span>
# <span>114분 </span>
# <span>
# <a href="/movie/sdb/browsing/bmovie.nhn?open=2020">2020</a>
# <a href="/movie/sdb/browsing/bmovie.nhn?open=20200122">.01.22</a> 개봉
#
#
#
# 				</span>
# <span>
# 					[국내]
#
# 							<a href="/movie/sdb/browsing/bmovie.nhn?grade=1001003">15세 관람가</a>
# </span>
# <span><a href="/movie/running/current.nhn?view=list&amp;tab=normal&amp;order=reserve">예매율 1위</a></span>
# <span class="uio_ntz_btn">
# <span class="ntz">누적관객<a class="help" href="#" id="boxofficeHelpButtonWide" title="누적관객 도움말 보기">누적관객 도움말</a></span>
# <span class="ly_ntz" id="boxofficeHelpLayerWide" style="display:none;">
# <span></span>
# <strong class="blind">네티즌 평점 도움말</strong>
# 						영화진흥위원회 영화관 입장권 통합전산망 제공
# 						<button class="btn_close" id="boxofficeHelpCloseButtonWide" type="button"><em>닫기</em></button>
# </span>
# </span><span class="count">257,799명<em>(01.22 기준)</em></span>
# </p>
# <div class="info_spec2">
# <dl class="step1">
# <dt>감독</dt>
# <dd>
# <a href="/movie/bi/pi/basic.nhn?code=217559">우민호</a>
# </dd>
# </dl>
# <dl class="step2">
# <dt>출연</dt>
# <dd>
# <a href="/movie/bi/pi/basic.nhn?code=1898">이병헌<span></span></a>,
#
#
#
#
#
#
#
#
#
# 									<a href="/movie/bi/pi/basic.nhn?code=48364">이성민<span></span></a>,
#
#
#
#
#
#
#
#
#
# 									<a href="/movie/bi/pi/basic.nhn?code=48376">곽도원<span></span></a>
# </dd>
# </dl>
# <a class="more" href="./detail.nhn?code=176306" title="더보기">더보기</a>
# </div>
# <div class="end_btn_area">
# <ul>
# <li><a class="btn_rsv _reserveHelpWide" href="/movie/bi/mi/reserve.nhn?code=176306" id="reserveWide" title="예매하기"><em>예매하기</em></a>
# <div class="ly_mileage _reserveHelpWide" id="reserveHelpWide" style="display:none">
# <span></span>영화관람후 평점을 작성하시면 <em>네이버페이 포인트 500원</em>을 드립니다! <a class="btn_close _reserveHelpWide" href="#" id="reserveHelpWideCloseButton"><em>닫기</em></a>
# </div>
# </li>
# <li>
# <!-- [D]btn_site_on 으로 컨트롤 -->
# <a class="btn_site" href="javascript:displayMovieHomepageLayerW();" id="movieHomePageButtonW" title="공식사이트"><em>공식사이트</em></a> <!-- 공식 사이트 레이어 -->
# <div class="ly_site" id="movieHomePageLayerW" style="display: none">
# <p><a href="http://namsan-showbox.co.kr/" target="_blank" title="해당 URL로 가기">http://namsan-showbox.co.kr/</a></p>
# <a class="btn_close" href="javascript:hideMovieHomepageLayerW();"><em>닫기</em></a>
# </div> <!-- //공식 사이트 레이어 -->
# </li>
# <li>
# <div class="u_likeit_module"></div>
# </li>
# </ul>
# </div>
# <div class="spi_area">
# <div class="naver-splugin" data-me-display="off" data-oninitialize="movie_oninitialize()" data-style="standard-v1-text" id="wideSpiLayer"></div>
# </div>
# </div>
# <!--[D] 성별 나이별 관람추이 -->
# <div class="viewing_graph">
# <h4 class="graph_title">성별·나이별 관람추이</h4>
# <div class="graph_wrap">
# <div class="donut_graph">
# <div class="graph_box" id="actualGenderGraph_wide" style="width: 100px;height:100px;">
# </div>
# <div class="graph_legend">
# <ul>
# <li>남자</li>
# <li>여자</li>
# </ul>
# </div>
# </div>
# <div class="bar_graph">
# <div class="graph_box">
# <strong class="graph_percent">1<span class="text_percent">%</span></strong>
# <div class="graph">
# <span class="bar_gauge" style="height: 1%"></span>
# </div>
# <strong class="graph_legend"><span class="num">10</span>대</strong>
# </div>
# <div class="graph_box">
# <strong class="graph_percent">36<span class="text_percent">%</span></strong>
# <div class="graph">
# <span class="bar_gauge" style="height: 36%"></span>
# </div>
# <strong class="graph_legend"><span class="num">20</span>대</strong>
# </div>
# <div class="graph_box high_percent">
# <strong class="graph_percent">39<span class="text_percent">%</span></strong>
# <div class="graph">
# <span class="bar_gauge" style="height: 39%"></span>
# </div>
# <strong class="graph_legend"><span class="num">30</span>대</strong>
# </div>
# <div class="graph_box">
# <strong class="graph_percent">17<span class="text_percent">%</span></strong>
# <div class="graph">
# <span class="bar_gauge" style="height: 17%"></span>
# </div>
# <strong class="graph_legend"><span class="num">40</span>대</strong>
# </div>
# <div class="graph_box">
# <strong class="graph_percent">8<span class="text_percent">%</span></strong>
# <div class="graph">
# <span class="bar_gauge" style="height: 8%"></span>
# </div>
# <strong class="graph_legend"><span class="num">50</span>대 <span class="ico_up"><span class="blind">이상</span></span></strong>
# </div>
# </div>
# </div>
# </div>
# <!--// 성별 나이별 관람추이 -->
# </div>
# <!-- //영화정보(wide) -->
# <!-- 영화정보(basic) -->
# <div class="mv_info_area">
# <div class="mv_info">
# <h3 class="h_movie">
# <a href="./basic.nhn?code=176306">남산의 부장들</a><!-- N=a:ifo.title --> <a class="opening" href="/movie/running/current.nhn?order=reserve"><em>상영중</em></a><!-- N=a:ifo.nbtn --></h3>
# <strong class="h_movie2" title="The Man Standing Next, 2018">The Man Standing Next, 2018</strong>
# <div class="main_score">
# <div class="score">
# <div class="uio_ntz_btn see">
# <span class="ntz _actualPointHelpBasic">
# <em class="blind">관람객 평점</em>
# <a class="help _actualPointHelpBasic" href="#" id="actualPointHelpButtonBasic">관람객 평점 도움말</a>
# </span>
# <div class="ly_ntz" id="actualPointHelpBasic" style="display:none" z-index="20">
# <span></span>
# 							관람객 평점은 네이버영화에서<br/>예매하고 실제 관람 후 이용자들이<br/>작성한 평점입니다.
# 							<button class="btn_close _actualPointHelpBasic" id="actualPointHelpCloseButtonBasic" type="button"><em>닫기</em></button>
# </div>
# <div class="ly_count" id="actualPointCountBasic" style="display:none">
# <span></span>
# 							참여 <em>135</em>명
# 						</div>
# </div>
# <a class="ntz_score" href="./point.nhn?code=176306&amp;onlyActualPointYn=Y#pointAfterTab" id="actualPointPersentBasic">
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:85.1%">관람객 평점 8.51점</span></span><em class="num8">8</em><em class="dot">.</em><em class="num5">5</em><em class="num1">1</em>
# </div>
# </a><!-- N=a:ifo.mgrating -->
# </div>
# <div class="score">
# <div class="spc_score_area">
# <a class="spc" href="./point.nhn?code=176306#pointExpertTab">
# <span class="spc_score"><em class="blind">기자 · 평론가 평점</em></span>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:70.0%"></span></span><em class="num7">7</em><em class="dot">.</em><em class="num0">0</em><em class="num0">0</em>
# </div>
# </a><!-- N=a:ifo.crating -->
# </div>
# </div>
# <div class="score score_left">
# <div class="uio_ntz_btn">
# <span class="ntz">
# <em class="blind">네티즌 평점</em><a class="help" href="#" id="pointHelpButtonBasic" title="네티즌 평점 도움말 보기">네티즌 평점 도움말</a>
# </span>
# <div class="ly_ntz" id="pointHelpBasic" style="display:none" z-index="20">
# <span></span>
# <strong class="blind">네티즌 평점 도움말</strong>
#
#
#
# 								국내 개봉작입니다. 관람하신 영화에 대한<br/> 평점을 남겨주세요. 네티즌 평점 뿐 아니라 블<br/>로그 영화 리뷰작성 시 등록한 별점도 함께<br/> 반영됩니다.
#
#
# 						<button class="btn_close" id="pointHelpCloseButtonBasic" type="button"><em>닫기</em></button>
# </div>
# <div class="ly_count" id="pointNetizenCountBasic" style="display:none">
# <span></span>
# 						참여 <em>2,913</em>명
# 					</div>
# </div>
# <div class="star_score">
# <a href="./point.nhn?code=176306#pointAfterTab" id="pointNetizenPersentBasic"><span class="st_off"><span class="st_on" style="width:74.8%"></span></span><em class="num7">7</em><em class="dot">.</em><em class="num4">4</em><em class="num8">8</em></a><!-- N=a:ifo.arating -->
# </div>
# </div>
# <div class="score" id="noPoint">
# <div class="my_score_area">
# <!--[D] 내평점이 없는경우 화살표를 없애기 위해 class="my"가 빠진다 -->
# <a href="./point.nhn?code=176306#pointAfterTab">
# <span class="my_score"><em class="blind">내 평점</em></span>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:0%">0점</span></span>
# <span class="btn_write">등록</span>
# </div>
# </a>
# </div>
# </div>
# <div class="score" id="existPoint" style="display : none">
# <div class="my_score_area">
# <a class="my" href="javascript:pointBasic.toggleMyPoint();">
# <span class="my_score">
# <em class="blind">내 평점</em>
# </span>
# <div class="star_score" id="starPoint">
# <span class="st_off"><span class="st_on" id="pointStar" style="width:0%"></span></span>
# </div>
# </a><!-- N=a:ifo.marating -->
# <div class="ly_my" id="myPointLayerBasic" style="display:none">
# <span id="pointText"></span><a class="btn_del" href="javascript:checkAlreadyPointAfterExist('basic', );" id="pointRemove">삭제</a>
# <a class="btn_close" href="javascript:pointBasic.toggleMyPoint();"><em>닫기</em></a>
# </div>
# </div>
# </div>
# </div>
# <dl class="info_spec">
# <dt class="step1"><em>개요()</em></dt>
# <dd>
# <p>
# <span>
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:ifo.genre -->
# </span>
# <span>
# <a href="/movie/sdb/browsing/bmovie.nhn?nation=KR">한국</a><!-- N=a:ifo.nation -->
# </span>
# <span>114분 </span>
# <span>
# <a href="/movie/sdb/browsing/bmovie.nhn?open=2020"> 2020</a><!-- N=a:ifo.year -->
# <a href="/movie/sdb/browsing/bmovie.nhn?open=20200122">.01.22</a><!-- N=a:ifo.day --> 개봉
#
#
#
# 					</span>
# </p>
# </dd>
# <dt class="step2"><em>감독</em></dt>
# <dd><p><a href="/movie/bi/pi/basic.nhn?code=217559">우민호</a><!-- N=a:ifo.director --></p></dd>
# <dt class="step3"><em>출연</em></dt>
# <dd><p><a href="/movie/bi/pi/basic.nhn?code=1898">이병헌</a><!-- N=a:ifo.actor -->, <a href="/movie/bi/pi/basic.nhn?code=48364">이성민</a><!-- N=a:ifo.actor -->, <a href="/movie/bi/pi/basic.nhn?code=48376">곽도원</a><!-- N=a:ifo.actor --></p><a class="more" href="detail.nhn?code=176306" title="더보기">더보기</a><!-- N=a:ifo.actmore --></dd>
# <dt class="step4"><em>등급</em></dt>
# <dd>
# <p>
# 						[국내]
#
# 							<a href="/movie/sdb/browsing/bmovie.nhn?grade=1001003">15세 관람가</a><!-- N=a:ifo.filmrate -->
# </p>
# </dd>
# <dt class="step9"><em>흥행</em></dt>
# <dd>
# <div class="step9_cont">
# <p class="rate"><a href="/movie/running/current.nhn?view=list&amp;tab=normal&amp;order=reserve">예매율 1위</a></p>
# <div class="uio_ntz_btn">
# <span class="ntz">누적관객<a class="help" href="#" id="boxofficeHelpButtonBasic" title="누적관객 도움말 보기">누적관객 도움말</a></span>
# <div class="ly_ntz" id="boxofficeHelpLayerBasic" style="display:none;">
# <span></span>
# <strong class="blind">네티즌 평점 도움말</strong>
# 									영화진흥위원회 영화관 입장권 통합전산망 제공
# 									<button class="btn_close" id="boxofficeHelpCloseButtonBasic" type="button"><em>닫기</em></button>
# </div>
# </div>
# <p class="count">257,799명<span>(01.22 기준)</span></p>
# </div>
# </dd>
# </dl>
# <!--[D] 성별 나이별 관람추이 -->
# <div class="viewing_graph">
# <h4 class="graph_title">성별·나이별 관람추이</h4>
# <div class="graph_wrap">
# <div class="donut_graph">
# <div class="graph_box" id="actualGenderGraph" style="width: 100px;height:100px;">
# <!--[D] 그래프 영역 -->
# </div>
# <div class="graph_legend">
# <ul>
# <li>남자</li>
# <li>여자</li>
# </ul>
# </div>
# </div>
# <div class="bar_graph">
# <div class="graph_box">
# <strong class="graph_percent">1<span class="text_percent">%</span></strong>
# <div class="graph">
# <span class="bar_gauge" style="height: 1%"></span>
# </div>
# ...
# 				jindo.$("myPointLayer").style.display = "";
# 			} else {
# 				jindo.$("myPointLayer").style.display = "none";
# 			}
# 		},
#
# 		del : function (existPointType, nid) {
# 			if (existPointType == "actualPoint") {
# 				if (confirm("관람객 평점 삭제시, 평점 작성으로 적립된 포인트는 회수됩니다. 평점을 삭제할까요?") == false) {
# 					return false;
# 				}
# 			} else {
# 				if (confirm("본인 삭제 시 복구할 수 없습니다.\n평점을 삭제하시겠습니까?") == false) {
# 					return false;
# 				}
# 			}
#
# 			var deleteApiUrl = "/api/internal/point/pointBeforeDelete.nhn";
# 			if (true) {
# 				deleteApiUrl = "/api/internal/point/pointAfterDelete.nhn";
# 			}
#
# 			var ajax = new jindo.$Ajax(deleteApiUrl, {
# 				method : "POST",
# 				async : false,
# 				onload : this.delCallback
# 			});
# 			ajax.header("ajax", "true");
# 			ajax.request({
# 				"nid":nid
# 			});
# 		},
#
# 		delCallback : function(req) {
# 			var returnValue = req.text();
#
# 			if(returnValue != "success"){
# 				alert(returnValue);
# 				return;
# 			}
#
# 			top.location.reload(true);
# 		}
# };
#
# function toggleDropBox(id) {
# 	wel = jindo.$Element(id);
# 	if (wel) {
# 		wel.toggle();
# 	}
# }
#
# function reservation(mcode, mtype, gcode, tcode, date, time, bOutLink) {
# 	var url = "/movie/reservation/index.nhn?";
# 	var param = "rmcode=" + mcode + "_" + mtype;
# 	param = param + "&gcode=" + gcode;
# 	param = param + "&tcode=" + tcode;
# 	param = param + "&date=" + date;
# 	param = param + "&time=" + time;
#
#
# 	if (bOutLink) {
# 		window.open(url + param);
# 	} else {
# 		location.href = url + param;
# 	}
# }
#
# function showPointListByNid(nid){
#
#
#
# 		location.href = location.protocol + "//" + location.hostname + "/movie/point/af/list.nhn?st=nickname&target=after&sword="+nid;
#
#
# }
#
# // 스포일러 감상평 내용 보기
# function showMovieReview(rvwIdx) {
#     jindo.$Element('_text_spo_' + rvwIdx).css('display', 'none');
#     jindo.$Element('_filtered_ment_' + rvwIdx).css('display', 'block');
# }
#
# // 감상평 펼쳐보기
# function unfoldPointMent(obj) {
#     var fullMent = jindo.$Element(obj).attr("data-src");
#     jindo.$Element(obj).parent().html(fullMent);
# }
#
# jindo.$Fn(function() {
#
# 		var elMakingnotePhase = jindo.$Element('makingnotePhase');
#
# 		if (elMakingnotePhase.height() == elMakingnotePhaseHeight) {
# 			elMakingnotePhase.className("con_tx");
# 			makingnotePhaseClassName = "con_tx";
# 		} else if (elMakingnotePhase.height() > elMakingnotePhaseHeight) {
# 			elMakingnotePhase.height(630);
# 			elMakingnotePhase.className("con_tx");
# 			makingnotePhaseClassName = "con_tx";
# 		}
#
# }).attach(document, "domready");
#
# if(false == true) {
# 	if(jindo.$Element("btn_interest_basic") != null && jindo.$Element("btn_notInterest_basic") != null) {
# 		jindo.$Element("btn_interest_basic").attach("click", function(e){
# 			e.stop(jindo.$Event.CANCEL_DEFAULT);
# 			queryAndUpdatePreference('176306','interest');
# 		});
#
# 		jindo.$Element("btn_notInterest_basic").attach("click", function(e){
# 			e.stop(jindo.$Event.CANCEL_DEFAULT);
# 			queryAndUpdatePreference('176306','notInterest');
# 		});
# 	}
# }
# 	var ctlToolTip = {
# 		toggleTooltip: function() {
# 			var status = jindo.$("aitems_tooltip").style.display = jindo.$("aitems_tooltip").style.display;
# 			jindo.$("aitems_tooltip").style.display = jindo.$("aitems_tooltip").style.display = status === "block"? "" : "block";
# 		},
# 	}
# </script>
# <script type="text/javascript">
# 	var sympathy = new Sympathy("176306", "after");
# </script>
# <!-- //content -->
# </div>
# <!-- //container -->
# <!-- footer -->
# <div id="footer">
# <div class="in_footer">
# <div class="foot_con">
# <ul>
# <li class="first"><a href="http://www.naver.com/rules/service.html" target="_blank">이용약관</a><!-- N=a:fot.agreement --></li>
# <li><a href="http://www.naver.com/rules/privacy.html" target="_blank"><strong>개인정보처리방침</strong></a><!-- N=a:fot.privacy --></li>
# <li><a href="http://www.naver.com/rules/disclaimer.html" target="_blank">책임의 한계와 법적고지</a><!-- N=a:fot.disclaimer --></li>
# <li><a href="https://help.naver.com/support/service/main.nhn?serviceNo=800" target="_blank">영화 고객센터</a><!-- N=a:fot.help --></li>
# </ul>
# <p class="info">본 콘텐츠의 저작권은 저작권자 또는 제공처에 있으며, 이를 무단 이용하는 경우 저작권법 등에 따라 법적 책임을 질 수 있습니다.</p>
# <p class="info">
# 					사업자등록번호 : 220-81-62517<span>통신판매업 신고번호</span> : 경기성남 제 2006 - 692호<span>대표이사 : 한성숙</span><span><a href="http://www.ftc.go.kr/info/bizinfo/communicationList.jsp">사업자등록정보 확인</a><!-- N=a:fot.bizinfo --></span><br/>
# 					주소 : 경기도 성남시 분당구 불정로 6 네이버 그린팩토리 <span>대표전화 : 1588-3820</span>
# </p>
# <address>
# <a class="logo" href="http://www.navercorp.com/" target="_blank"><img alt="NAVER" height="11" src="https://ssl.pstatic.net/static/movie/2013/07/logo_naver.png" width="63"/></a><!-- N=a:fot.nhn -->
# <em>Copyright ©</em>
# <a href="http://www.navercorp.com/" target="_blank">NAVER Corp.</a><!-- N=a:fot.corp -->
# <span>All Rights Reserved.</span>
# </address>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#
# if (false) {
# 	var alertType = "NONE";
# 	var koreanTitle = "";
# 	var movieCode = "0";
# 	var userReserveCount = "0";
# 	var todayDatetime = "20200123135149";
# 	var endDatetimeAfterTwoDays = "00000000000000";
#
#
# 	if (movieCode > 0) {
# 		openWriteActualPointAlert (alertType, koreanTitle, movieCode, userReserveCount, todayDatetime, endDatetimeAfterTwoDays);
# 	}
# }
#
# function openWriteActualPointAlert (alertType, koreanTitle, movieCode, count, today, endDate) {
# 	if (alertType == "ONE") {
# 		setCookieLastUserReserveDate(today, endDate);
# 		if (confirm("관람하신 " + koreanTitle + "에\n평점 등록 시 네이버페이 포인트 500원 적립!\n지금 평점쓰기 메뉴로 이동하시겠습니까?")) {
# 			top.location.href = "https://movie.naver.com/movie/bi/mi/point.nhn?code=" + movieCode;
# 		}
# 	} else if (alertType == "MORE") {
# 		setCookieLastUserReserveDate(today, endDate);
# 		if (confirm("관람하신 작품에 평점을 등록해주세요\n작품당 네이버페이 포인트 500원씩 적립!\n평점 미등록작 리스트를 확인하시겠습니까?")) {
# 			top.location.href = "http://ticket.movie.naver.com/Order/OverdueList.aspx";
# 		}
# 	}
# }
#
# function setCookieLastUserReserveDate(today, endDate) {
# 	var cookieForNotOpenActualPointPopup = jindo.$Cookie();
#
#
# 	cookieForNotOpenActualPointPopup.remove("lastUserReserveDatetime");
# 	cookieForNotOpenActualPointPopup.remove("lastUserReserveCheckDatetime");
#
# 	cookieForNotOpenActualPointPopup.set("lastUserReserveDatetime", endDate, 9999, "movie.naver.com");
# 	cookieForNotOpenActualPointPopup.set("lastUserReserveCheckDatetime", today, 9999, "movie.naver.com");
# }
#
# </script>
# <script type="text/javascript">
#
#
#
#
#
# 			var alertMessage = "지원되지 않는 브라우저로 서비스 이용에 제한이 있습니다.";
#
#
#
# 	function getBrowser() {
# 		var ua = navigator.userAgent;
# 		if (/NAVER/.test(ua)) {
# 			return "NAVER_APP";
# 		} else if (/IEMobile/.test(ua)) {
# 			return "INTERNET_EXPLORER_MOBILE";
# 		} else if (/MSIE/.test(ua) || /Trident/.test(ua)) {
# 			return "INTERNET_EXPLORER";
# 		} else if (/Firefox/.test(ua)) {
# 			return "FIREFOX";
# 		} else if (/Opera\//.test(ua) || /OPR\//.test(ua)) {
# 			return "OPERA";
# 		}  else if (/Swing\//.test(ua)) {
# 			return "SWING";
# 		} else if (/Chrome\//.test(ua) || /CriOS\//.test(ua)) {
# 			return "CHROME";
# 		} else if (/BAND\//.test(ua)) {
# 			return "BAND_APP";
# 		} else if (/FBAN\/FBIOS/.test(ua)) {
# 			return "FACEBOOK_APP";
# 		} else if (/Twitter/.test(ua)) {
# 			return "TWITTER_APP";
# 		} else if (/KAKAOTALK/.test(ua)) {
# 			return "KAKAOTALK_APP";
# 		} else if (/Android/.test(ua) && /Safari/.test(ua)) {
# 			return "ANDROID_INTERNET_APP";
# 		} else if (/Safari/.test(ua)) {
# 			return "SAFARI";
# 		}
#
# 		return "";
# 	}
#
# 	if (getBrowser() === "UNKNOWN" && jindo.$Cookie().get("notSupportBrowserAlert") != 'true') {
# 		alert(alertMessage);
# 		jindo.$Cookie().set("notSupportBrowserAlert", "true", "9999", "movie.naver.com");
# 	}
#
#
# </script>
# <!-- //footer -->
# </div>
# <script type="text/javascript">
# var isRecentTab = false;
#
# jindo.$Fn(function (we) {
#
# 	    // 윈도우창 리사이징에 따른 레이아웃 1/2단 관리
# 	    var oViewMode = new nhn.movie.end.ViewMode();
#
#
# 	// 상단 검색영역
# 	var oSearch = new nhn.movie.Search({
# 		area : "jSearchArea",
# 		autosearch : "https://auto-movie.naver.com/ac?q_enc=UTF-8&st=1&r_lt=1&n_ext=1&t_koreng=1&r_format=json&r_enc=UTF-8&r_unicode=0&r_escape=1&q=",
# 		movelink : "/movie/bi/mi/basic.nhn?code=",
# 		peoplelink : "/movie/bi/pi/basic.nhn?code="
# 	});
#
#     // 좌측 LNB
#     var oLNB = new nhn.movie.LNB();
# 	if( typeof oViewMode != "undefined") {
# 		oViewMode.attach('change', jindo.$Fn(oLNB.update, oLNB).bind());
# 	}
#
#     // 2단일때, 2열에 상단 회색 라인 없애기
# 	if( typeof oViewMode != "undefined") {
# 	    oViewMode.attach('change', function (oEvent) {
# 	        var welSecondSectionGroup = jindo.$Element('content').queryAll('.section_group')[1];
# 	        var wel2column1rowSection;
#
# 	        if (welSecondSectionGroup) {
# 	            wel2column1rowSection = welSecondSectionGroup.query('.obj_section');
#
# 	            if (oEvent.sStyle == 'wide') {
# 	                wel2column1rowSection.addClass('noline');
# 	            } else {
# 	                wel2column1rowSection.removeClass('noline');
# 	            }
# 	        }
#
# 		    //포토 묻어가기
# 		    if( typeof oPhoto != "undefined" ){
# 			    if (oEvent.sStyle == 'wide') {
# 				    oPhoto.setWide("wide");
# 			    } else {
# 				    oPhoto.setWide("basic");
# 			    }
# 		    }
# 		    // 비디오 묻어가기
# 		    if( typeof oMovie != "undefined" ){
# 			    if (oEvent.sStyle == 'wide') {
# 				    oMovie.setWide("wide", 1);
# 			    } else {
# 				    oMovie.setWide("basic", 1);
# 			    }
# 		    }
#
# 	    });
# 	}
#
#     // 상단썸네일영역
#
#
# 		var welTopArea = jindo.$Element('_TopArea');
# 		new nhn.movie.end.TopAreaThumbnailExpander(welTopArea.query('.current_mv_list .top_poster_area')).attach({
# 		    click: function (oEvent) {
# 		        clickcr(oEvent.element, 'rnk.nimg', '', '', event);
# 		    }
# 		});
# 		new nhn.movie.end.TopAreaThumbnailExpander(welTopArea.query('.expected_mv_list .top_poster_area')).attach({
# 		    click: function (oEvent) {
# 		        clickcr(oEvent.element, 'rnk.simg', '', '', event);
# 		    }
# 		});
# 		var oTopAreaManager = new nhn.movie.end.movie.TopAreaManager(welTopArea);
# 		if ( typeof oViewMode == "undefined" || oViewMode.is('basic') ) {
# 		    oTopAreaManager.enableNavigationBtns();
# 		} else {
# 		    oTopAreaManager.disableNavigationBtns();
# 		}
# 		if( typeof oViewMode != "undefined" ) {
# 			var tempEvent = {};
# 			oViewMode.attach('change', jindo.$Fn(oTopAreaManager.onViewModeChange, oTopAreaManager).bind());
#
# 		    if (oViewMode.is('basic') && oViewMode.serverSstyle != 'basic') {
# 		    	tempEvent.sStyle = 'basic';
# 			    oTopAreaManager.onViewModeChange(tempEvent);
# 		    } else if (oViewMode.is('wide') && oViewMode.serverSstyle != 'wide') {
# 		    	tempEvent.sStyle = 'wide';
# 			    oTopAreaManager.onViewModeChange(tempEvent);
# 		    }
# 		}
#
#
#
#
#     var waelScriptOrderList = jindo.$ElementList('._gnb_another_service_layer');
#
#     jindo.$A(waelScriptOrderList.$value()).forEach(function(value, index, array) {
# 		jindo.$Fn(reviewOrderLayerToggle, this).attach(value, "blur");
# 	});
#     //자동닫힘 기능 끝.
#
#   //영화검색 결과에서 포커스 아웃될 경우, 검색 결과를 지우도록 변경.
#     jindo.$Element("lnb_gonaver").attach("focus",function(e){
#
#     	jindo.$Element('search_placeholder').attr({
#     		"style" : "display: inline;"
#     	})
#     	jindo.$Element('ipt_tx_srch').$value().value="";
#
#     	if(jindo.$Element("jAutoComplate") != null){
#     		jindo.$Element("jAutoComplate").hide();
#     	}
#     });
#
#
#     /**
#      * 영화 END 페이지
#      */
#     var welMovieInfoWideArea = jindo.$Element(jindo.$$.getSingle('.wide_info_area'));
#     var welMovieInfoBasicArea = jindo.$Element(jindo.$$.getSingle('.mv_info_area'));
#     if ( oViewMode.is('basic') ) {
#         welMovieInfoWideArea.hide();
#         welMovieInfoBasicArea.show();
#       	if (window["createActualGenderPointGraph"]) createActualGenderPointGraph();
#     } else {
#         welMovieInfoBasicArea.hide();
#         welMovieInfoWideArea.show();
#       	if(window["createActualGenderPointGraph"]) createActualGenderPointGraph(true);
#     }
#     oViewMode.attach('change', function (oEvent) {
#         // 기본정보 영역 변경
#         if ( oEvent.sStyle === 'basic' ) {
#             welMovieInfoWideArea.hide();
#             welMovieInfoBasicArea.show();
#           if(window["createActualGenderPointGraph"]) createActualGenderPointGraph();
#         } else {
#             welMovieInfoBasicArea.hide();
#             welMovieInfoWideArea.show();
#
#           if(window["createActualGenderPointGraph"]) createActualGenderPointGraph(true);
#         }
#     });
#
#
#
#         /* 영화주요정보 탭 */
#
#         // 포토영역
#         new nhn.movie.end.MainPhotoArea(
#             jindo.$('_MainPhotoArea'), // Element
#             '/movie/bi/mi/photoListJson.nhn?movieCode=176306', // List API URL
#             {
#             	"lists":[
#
#             			{"nid":0,"imageNid":6672894,"imageType":"STILLCUT","movieCode":176306,"gdid":"080005ea_00000065d1fe","adult":false,"fullImageUrl427px":"https://movie-phinf.pstatic.net/20191022_96/1571723738033pln2A_JPEG/movie_image.jpg?type=m427_320_2"},
#
#             			{"nid":0,"imageNid":6678560,"imageType":"STILLCUT","movieCode":176306,"gdid":"080005ea_00000065e820","adult":false,"fullImageUrl427px":"https://movie-phinf.pstatic.net/20191217_14/1576546046036OeSCA_JPEG/movie_image.jpg?type=m427_320_2"},
#
#             			{"nid":0,"imageNid":6677310,"imageType":"STILLCUT","movieCode":176306,"gdid":"080005ea_00000065e33e","adult":false,"fullImageUrl427px":"https://movie-phinf.pstatic.net/20191203_145/1575341088479SPVmw_JPEG/movie_image.jpg?type=m427_320_2"},
#
#             			{"nid":0,"imageNid":6677311,"imageType":"STILLCUT","movieCode":176306,"gdid":"080005ea_00000065e33f","adult":false,"fullImageUrl427px":"https://movie-phinf.pstatic.net/20191203_149/1575335792225L3pvX_JPEG/movie_image.jpg?type=m427_320_2"},
#
#             			{"nid":0,"imageNid":6677312,"imageType":"STILLCUT","movieCode":176306,"gdid":"080005ea_00000065e340","adult":false,"fullImageUrl427px":"https://movie-phinf.pstatic.net/20191203_31/1575335792698IdBVQ_JPEG/movie_image.jpg?type=m427_320_2"},
#
#             			{"nid":0,"imageNid":6677313,"imageType":"STILLCUT","movieCode":176306,"gdid":"080005ea_00000065e341","adult":false,"fullImageUrl427px":"https://movie-phinf.pstatic.net/20191203_275/1575335793358M4VMK_JPEG/movie_image.jpg?type=m427_320_2"},
#
#             			{"nid":0,"imageNid":6677314,"imageType":"STILLCUT","movieCode":176306,"gdid":"080005ea_00000065e342","adult":false,"fullImageUrl427px":"https://movie-phinf.pstatic.net/20191203_23/1575335793886y3Khw_JPEG/movie_image.jpg?type=m427_320_2"},
#
#             			{"nid":0,"imageNid":6677315,"imageType":"STILLCUT","movieCode":176306,"gdid":"080005ea_00000065e343","adult":false,"fullImageUrl427px":"https://movie-phinf.pstatic.net/20191203_216/1575335794370xwx0D_JPEG/movie_image.jpg?type=m427_320_2"}
#
#             	]
#             }, // First List Object
#             jindo.$('mainPhotoViewIndex')
#         ).attach('updated', function (oEvent) {
#             var sRnd = (new Date()).getTime();
#             var sb = [];
#             var _displayNIndex = eval(oEvent.nIndex) + 1;
#
#             // 현재 포토 위치
#             jindo.$Element('mainPhotoViewIndex').text(_displayNIndex);
#
#             // 포토 조회수
#             new jindo.$Ajax('/movie/bi/mi/photoViewCount.nhn?imageNid=' + oEvent.imageNid, {
#                 method : 'get',
#                 onload : function(res){}
#             }).request();
#
#             // NDS
#             try {
#                 lcs_do();
#             } catch(e){}
#
#             // 코리안클릭 PV집계
# 			sb.push('<iframe height="0" frameborder="0" width="0" scrolling="no" src="');
# 			sb.push('/movie/bi/mi/photoViewCountDummy.nhn?_timestamp=' + sRnd);
# 			sb.push('"></iframe>');
# 			var sHtml = sb.join("");
# 			var elContent = jindo.$Element("footer");
# 			elContent.appendHTML(sHtml);
#         });
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# }).attach(document, 'domready');
# /**
#  * 기타 공통
#  */
# jindo.$Fn(function() {
#     try{ lcs_do(); } catch(e){}
# }).attach(window, "pageshow");
# </script>
# <script type="text/javascript">
# 	//nClick 초기화 영역
# 	//클릭로그 집계 코드 추가
# 	var ccsrv="cc.naver.com";
# 	var nclk_evt = 1;
#
# 	nclk_do();
# 	//nClick 초기화 영역 끝
# </script>
# </body>
# </html>

# %%
# 상단에 영화 목록을 가지고 있는 ul 태그를 가져온다.
ul_tag = soup.find('ul', class_ = 'top_thumb_lst')
ul_tag
# Out:
# <ul class="top_thumb_lst">
# <li class="on" data-title="남산의 부장들"><a href="/movie/bi/mi/basic.nhn?code=176306"><img alt="남산의 부장들" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200103_41/1578032244761ejKMX_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="히트맨"><a href="/movie/bi/mi/basic.nhn?code=185838"><img alt="히트맨" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200122_181/15796574636309Fux2_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="미스터 주: 사라진 VIP"><a href="/movie/bi/mi/basic.nhn?code=177509"><img alt="미스터 주: 사라진 VIP" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200122_11/15796766202282GrU2_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="스파이 지니어스"><a href="/movie/bi/mi/basic.nhn?code=172780"><img alt="스파이 지니어스" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200120_187/157948230962440pnt_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="해치지않아"><a href="/movie/bi/mi/basic.nhn?code=180025"><img alt="해치지않아" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200115_223/1579061805057fDTGd_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="닥터 두리틀"><a href="/movie/bi/mi/basic.nhn?code=159866"><img alt="닥터 두리틀" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191226_207/1577328208589oxfYb_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="타오르는 여인의 초상"><a href="/movie/bi/mi/basic.nhn?code=185282"><img alt="타오르는 여인의 초상" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191220_49/1576828214038i4ukE_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="나쁜 녀석들 : 포에버"><a href="/movie/bi/mi/basic.nhn?code=76960"><img alt="나쁜 녀석들 : 포에버" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200107_50/1578361868623t7Qp6_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="하이큐!! 땅 VS 하늘"><a href="/movie/bi/mi/basic.nhn?code=191431"><img alt="하이큐!! 땅 VS 하늘" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200117_26/1579249737548VjD7N_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="오즈의 마법사: 요술구두와 말하는 책"><a href="/movie/bi/mi/basic.nhn?code=190336"><img alt="오즈의 마법사: 요술구두와 말하는 책" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191219_69/15767213057872nskQ_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="백두산"><a href="/movie/bi/mi/basic.nhn?code=187940"><img alt="백두산" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191219_263/15767415637757HPgg_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="스타워즈: 라이즈 오브 스카이워커"><a href="/movie/bi/mi/basic.nhn?code=144694"><img alt="스타워즈: 라이즈 오브 스카이워커" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200108_148/1578462346140MWVbW_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="겨울왕국 2"><a href="/movie/bi/mi/basic.nhn?code=136873"><img alt="겨울왕국 2" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191121_221/1574298335357mqgLk_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="사마에게"><a href="/movie/bi/mi/basic.nhn?code=184571"><img alt="사마에게" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191224_60/1577155153773iLYXG_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="파바로티"><a href="/movie/bi/mi/basic.nhn?code=185357"><img alt="파바로티" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191202_163/1575249627261QLaXz_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# </ul>

# %%
# a 태그들을 가져온다.
a_list = ul_tag.find_all('a')
a_list
# Out:
# [<a href="/movie/bi/mi/basic.nhn?code=176306"><img alt="남산의 부장들" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200103_41/1578032244761ejKMX_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a>,
#  <a href="/movie/bi/mi/basic.nhn?code=185838"><img alt="히트맨" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200122_181/15796574636309Fux2_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a>,
#  <a href="/movie/bi/mi/basic.nhn?code=177509"><img alt="미스터 주: 사라진 VIP" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200122_11/15796766202282GrU2_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a>,
#  <a href="/movie/bi/mi/basic.nhn?code=172780"><img alt="스파이 지니어스" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200120_187/157948230962440pnt_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a>,
#  <a href="/movie/bi/mi/basic.nhn?code=180025"><img alt="해치지않아" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200115_223/1579061805057fDTGd_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a>,
#  <a href="/movie/bi/mi/basic.nhn?code=159866"><img alt="닥터 두리틀" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191226_207/1577328208589oxfYb_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a>,
#  <a href="/movie/bi/mi/basic.nhn?code=185282"><img alt="타오르는 여인의 초상" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191220_49/1576828214038i4ukE_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a>,
#  <a href="/movie/bi/mi/basic.nhn?code=76960"><img alt="나쁜 녀석들 : 포에버" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200107_50/1578361868623t7Qp6_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a>,
#  <a href="/movie/bi/mi/basic.nhn?code=191431"><img alt="하이큐!! 땅 VS 하늘" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200117_26/1579249737548VjD7N_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a>,
#  <a href="/movie/bi/mi/basic.nhn?code=190336"><img alt="오즈의 마법사: 요술구두와 말하는 책" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191219_69/15767213057872nskQ_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a>,
#  <a href="/movie/bi/mi/basic.nhn?code=187940"><img alt="백두산" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191219_263/15767415637757HPgg_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a>,
#  <a href="/movie/bi/mi/basic.nhn?code=144694"><img alt="스타워즈: 라이즈 오브 스카이워커" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200108_148/1578462346140MWVbW_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a>,
#  <a href="/movie/bi/mi/basic.nhn?code=136873"><img alt="겨울왕국 2" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191121_221/1574298335357mqgLk_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a>,
#  <a href="/movie/bi/mi/basic.nhn?code=184571"><img alt="사마에게" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191224_60/1577155153773iLYXG_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a>,
#  <a href="/movie/bi/mi/basic.nhn?code=185357"><img alt="파바로티" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20191202_163/1575249627261QLaXz_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a>]

# %%
# a 태크의 href 속성 값을 가져온다.
code_list = []

for a_tag in a_list:
    href = a_tag.attrs['href']
    str1 = href.split('=')
    code = str1[1]
#     print(code)
    code_list.append(code)
# print(code_list)
# Out:
# ['176306', '185838', '177509', '172780', '180025', '159866', '185282', '76960', '191431', '190336', '187940', '144694', '136873', '184571', '185357']

# %% [markdown]
# #### 영화 140자 평 데이터를 추출

# %%
# 영화 코드를 받아 응답 결과를 반환하는 함수
def getHTML(code):
    site = f'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code={code}&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'
    # 요청한다.
    response = requests.get(site)
    return response.text

# %%
# 전체 페이지 수를 반환하는 함수
def getPageCnt(html):
    # bs4 객체 생성
    soup = bs4.BeautifulSoup(html,'lxml')
    # 전체 글 개수를 가져온다.
    div_tag = soup.find('div', class_='score_total')
    em_tag = div_tag.find('em')
    str_total_cnt = em_tag.text.replace(',','')
    str_total_cnt = int(str_total_cnt)
    
    # 페이지 수를 계산한다.
    page_cnt = str_total_cnt // 10
    if str_total_cnt % 10 >0:
        page_cnt = page_cnt + 1
    return page_cnt

# %%
# 현재 페이지에서 140자 평 데이터를 가져온다.
def get140comment(code, page):
    site = f'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code={code}&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page={page}'
    # 요청한다.
    response = requests.get(site)
    # bs4 객체를 생성
    soup = bs4.BeautifulSoup(response.text, 'lxml')
    # 데이터를 가지고 있는 div 태그를 가져온다.
    div_tag = soup.find('div', class_='score_result')
    # 내부에 있는 li 태그들을 가져온다.
    li_list = div_tag.find_all('li')
    
    for li_tag in li_list:
        # 별점을 가져온다.
        star_score_tag = li_tag.find('div',class_='star_score')
        em_tag = star_score_tag.find('em')
        star_score = em_tag.text # 별점
        
        # 평점글을 가져온다.
        score_reple_tag = li_tag.find('div',class_='score_reple')
        span_list = score_reple_tag.find_all('span')
        if len(span_list) > 2:   # 관람객 평점
            score_reple = span_list[1].text.strip()
            writer_id = span_list[2].text.strip()
        else:                    # 일반
            score_reple = span_list[0].text.strip()
            writer_id = span_list[1].text.strip()
        
        # 작성 날짜
        dl_tag = li_tag.find('dl')
        em_list = dl_tag.find_all('em')
        write_date = em_list[1].text
        
        reple_tuple = star_score, score_reple, writer_id, write_date
        
        # 수집한 데이터를 저장한다.
        
        if os.path.isfile(f'movie_data_{code}.csv') == False:
            columns = ['star_score', 'score_reple', 'writer_id', 'write_date']
            df1 = pandas.DataFrame([reple_tuple], columns=columns)
            df1.to_csv(f'movie_data_{code}.csv', index=False, encoding='utf-8-sig')
        else:
            df1 = pandas.DataFrame([reple_tuple])
            df1.to_csv(f'movie_data_{code}.csv', mode='a', index=False, header=False, encoding='utf-8-sig')

# %%
code_list=['156464']
for movie_code in code_list:
    html = getHTML(movie_code)
    page_cnt = getPageCnt(html)

    # 페이지 수만큼 반복
    for idx in range(1, page_cnt+1):
        time.sleep(0.005)
        print(f'code : {movie_code}, page : {idx} / {page_cnt}')
        get140comment(movie_code, idx)
print('수집 완료')
# Out:
# code : 156464, page : 1 / 3890
# code : 156464, page : 2 / 3890
# code : 156464, page : 3 / 3890
# code : 156464, page : 4 / 3890
# code : 156464, page : 5 / 3890
# code : 156464, page : 6 / 3890
# code : 156464, page : 7 / 3890
# code : 156464, page : 8 / 3890
# code : 156464, page : 9 / 3890
# code : 156464, page : 10 / 3890
# code : 156464, page : 11 / 3890
# code : 156464, page : 12 / 3890
# code : 156464, page : 13 / 3890
# code : 156464, page : 14 / 3890
# code : 156464, page : 15 / 3890
# code : 156464, page : 16 / 3890
# code : 156464, page : 17 / 3890
# code : 156464, page : 18 / 3890
# code : 156464, page : 19 / 3890
# code : 156464, page : 20 / 3890
# code : 156464, page : 21 / 3890
# code : 156464, page : 22 / 3890
# code : 156464, page : 23 / 3890
# code : 156464, page : 24 / 3890
# code : 156464, page : 25 / 3890
# code : 156464, page : 26 / 3890
# code : 156464, page : 27 / 3890
# code : 156464, page : 28 / 3890
# code : 156464, page : 29 / 3890
# code : 156464, page : 30 / 3890
# code : 156464, page : 31 / 3890
# code : 156464, page : 32 / 3890
# code : 156464, page : 33 / 3890
# code : 156464, page : 34 / 3890
# code : 156464, page : 35 / 3890
# code : 156464, page : 36 / 3890
# code : 156464, page : 37 / 3890
# code : 156464, page : 38 / 3890
# code : 156464, page : 39 / 3890
# code : 156464, page : 40 / 3890
# code : 156464, page : 41 / 3890
# code : 156464, page : 42 / 3890
# code : 156464, page : 43 / 3890
# code : 156464, page : 44 / 3890
# code : 156464, page : 45 / 3890
# code : 156464, page : 46 / 3890
# code : 156464, page : 47 / 3890
# code : 156464, page : 48 / 3890
# code : 156464, page : 49 / 3890
# code : 156464, page : 50 / 3890
# code : 156464, page : 51 / 3890
# code : 156464, page : 52 / 3890
# code : 156464, page : 53 / 3890
# code : 156464, page : 54 / 3890
# code : 156464, page : 55 / 3890
# code : 156464, page : 56 / 3890
# code : 156464, page : 57 / 3890
# code : 156464, page : 58 / 3890
# code : 156464, page : 59 / 3890
# code : 156464, page : 60 / 3890
# code : 156464, page : 61 / 3890
# code : 156464, page : 62 / 3890
# code : 156464, page : 63 / 3890
# code : 156464, page : 64 / 3890
# code : 156464, page : 65 / 3890
# code : 156464, page : 66 / 3890
# code : 156464, page : 67 / 3890
# code : 156464, page : 68 / 3890
# code : 156464, page : 69 / 3890
# code : 156464, page : 70 / 3890
# code : 156464, page : 71 / 3890
# code : 156464, page : 72 / 3890
# code : 156464, page : 73 / 3890
# code : 156464, page : 74 / 3890
# code : 156464, page : 75 / 3890
# code : 156464, page : 76 / 3890
# code : 156464, page : 77 / 3890
# code : 156464, page : 78 / 3890
# code : 156464, page : 79 / 3890
# code : 156464, page : 80 / 3890
# code : 156464, page : 81 / 3890
# code : 156464, page : 82 / 3890
# code : 156464, page : 83 / 3890
# code : 156464, page : 84 / 3890
# code : 156464, page : 85 / 3890
# code : 156464, page : 86 / 3890
# code : 156464, page : 87 / 3890
# code : 156464, page : 88 / 3890
# code : 156464, page : 89 / 3890
# code : 156464, page : 90 / 3890
# code : 156464, page : 91 / 3890
# code : 156464, page : 92 / 3890
# code : 156464, page : 93 / 3890
# code : 156464, page : 94 / 3890
# code : 156464, page : 95 / 3890
# code : 156464, page : 96 / 3890
# code : 156464, page : 97 / 3890
# code : 156464, page : 98 / 3890
# code : 156464, page : 99 / 3890
# code : 156464, page : 100 / 3890
# code : 156464, page : 101 / 3890
# code : 156464, page : 102 / 3890
# code : 156464, page : 103 / 3890
# code : 156464, page : 104 / 3890
# code : 156464, page : 105 / 3890
# code : 156464, page : 106 / 3890
# code : 156464, page : 107 / 3890
# code : 156464, page : 108 / 3890
# code : 156464, page : 109 / 3890
# code : 156464, page : 110 / 3890
# code : 156464, page : 111 / 3890
# code : 156464, page : 112 / 3890
# code : 156464, page : 113 / 3890
# code : 156464, page : 114 / 3890
# code : 156464, page : 115 / 3890
# code : 156464, page : 116 / 3890
# code : 156464, page : 117 / 3890
# code : 156464, page : 118 / 3890
# code : 156464, page : 119 / 3890
# code : 156464, page : 120 / 3890
# code : 156464, page : 121 / 3890
# code : 156464, page : 122 / 3890
# code : 156464, page : 123 / 3890
# code : 156464, page : 124 / 3890
# code : 156464, page : 125 / 3890
# code : 156464, page : 126 / 3890
# code : 156464, page : 127 / 3890
# code : 156464, page : 128 / 3890
# code : 156464, page : 129 / 3890
# code : 156464, page : 130 / 3890
# code : 156464, page : 131 / 3890
# code : 156464, page : 132 / 3890
# code : 156464, page : 133 / 3890
# code : 156464, page : 134 / 3890
# code : 156464, page : 135 / 3890
# code : 156464, page : 136 / 3890
# code : 156464, page : 137 / 3890
# code : 156464, page : 138 / 3890
# code : 156464, page : 139 / 3890
# code : 156464, page : 140 / 3890
# code : 156464, page : 141 / 3890
# code : 156464, page : 142 / 3890
# code : 156464, page : 143 / 3890
# code : 156464, page : 144 / 3890
# code : 156464, page : 145 / 3890
# code : 156464, page : 146 / 3890
# code : 156464, page : 147 / 3890
# code : 156464, page : 148 / 3890
# code : 156464, page : 149 / 3890
# code : 156464, page : 150 / 3890
# code : 156464, page : 151 / 3890
# code : 156464, page : 152 / 3890
# code : 156464, page : 153 / 3890
# code : 156464, page : 154 / 3890
# code : 156464, page : 155 / 3890
# code : 156464, page : 156 / 3890
# code : 156464, page : 157 / 3890
# code : 156464, page : 158 / 3890
# code : 156464, page : 159 / 3890
# code : 156464, page : 160 / 3890
# code : 156464, page : 161 / 3890
# code : 156464, page : 162 / 3890
# code : 156464, page : 163 / 3890
# code : 156464, page : 164 / 3890
# code : 156464, page : 165 / 3890
# code : 156464, page : 166 / 3890
# code : 156464, page : 167 / 3890
# code : 156464, page : 168 / 3890
# code : 156464, page : 169 / 3890
# code : 156464, page : 170 / 3890
# code : 156464, page : 171 / 3890
# code : 156464, page : 172 / 3890
# code : 156464, page : 173 / 3890
# code : 156464, page : 174 / 3890
# code : 156464, page : 175 / 3890
# code : 156464, page : 176 / 3890
# code : 156464, page : 177 / 3890
# code : 156464, page : 178 / 3890
# code : 156464, page : 179 / 3890
# code : 156464, page : 180 / 3890
# code : 156464, page : 181 / 3890
# code : 156464, page : 182 / 3890
# code : 156464, page : 183 / 3890
# code : 156464, page : 184 / 3890
# code : 156464, page : 185 / 3890
# code : 156464, page : 186 / 3890
# code : 156464, page : 187 / 3890
# code : 156464, page : 188 / 3890
# code : 156464, page : 189 / 3890
# code : 156464, page : 190 / 3890
# code : 156464, page : 191 / 3890
# code : 156464, page : 192 / 3890
# code : 156464, page : 193 / 3890
# code : 156464, page : 194 / 3890
# code : 156464, page : 195 / 3890
# code : 156464, page : 196 / 3890
# code : 156464, page : 197 / 3890
# code : 156464, page : 198 / 3890
# code : 156464, page : 199 / 3890
# code : 156464, page : 200 / 3890
# code : 156464, page : 201 / 3890
# code : 156464, page : 202 / 3890
# code : 156464, page : 203 / 3890
# code : 156464, page : 204 / 3890
# code : 156464, page : 205 / 3890
# code : 156464, page : 206 / 3890
# code : 156464, page : 207 / 3890
# code : 156464, page : 208 / 3890
# code : 156464, page : 209 / 3890
# code : 156464, page : 210 / 3890
# code : 156464, page : 211 / 3890
# code : 156464, page : 212 / 3890
# code : 156464, page : 213 / 3890
# code : 156464, page : 214 / 3890
# code : 156464, page : 215 / 3890
# code : 156464, page : 216 / 3890
# code : 156464, page : 217 / 3890
# code : 156464, page : 218 / 3890
# code : 156464, page : 219 / 3890
# code : 156464, page : 220 / 3890
# code : 156464, page : 221 / 3890
# code : 156464, page : 222 / 3890
# code : 156464, page : 223 / 3890
# code : 156464, page : 224 / 3890
# code : 156464, page : 225 / 3890
# code : 156464, page : 226 / 3890
# code : 156464, page : 227 / 3890
# code : 156464, page : 228 / 3890
# code : 156464, page : 229 / 3890
# code : 156464, page : 230 / 3890
# code : 156464, page : 231 / 3890
# code : 156464, page : 232 / 3890
# code : 156464, page : 233 / 3890
# code : 156464, page : 234 / 3890
# code : 156464, page : 235 / 3890
# code : 156464, page : 236 / 3890
# code : 156464, page : 237 / 3890
# code : 156464, page : 238 / 3890
# code : 156464, page : 239 / 3890
# code : 156464, page : 240 / 3890
# code : 156464, page : 241 / 3890
# code : 156464, page : 242 / 3890
# code : 156464, page : 243 / 3890
# code : 156464, page : 244 / 3890
# code : 156464, page : 245 / 3890
# code : 156464, page : 246 / 3890
# code : 156464, page : 247 / 3890
# code : 156464, page : 248 / 3890
# code : 156464, page : 249 / 3890
# code : 156464, page : 250 / 3890
# code : 156464, page : 251 / 3890
# code : 156464, page : 252 / 3890
# code : 156464, page : 253 / 3890
# code : 156464, page : 254 / 3890
# code : 156464, page : 255 / 3890
# code : 156464, page : 256 / 3890
# code : 156464, page : 257 / 3890
# code : 156464, page : 258 / 3890
# code : 156464, page : 259 / 3890
# code : 156464, page : 260 / 3890
# code : 156464, page : 261 / 3890
# code : 156464, page : 262 / 3890
# code : 156464, page : 263 / 3890
# code : 156464, page : 264 / 3890
# code : 156464, page : 265 / 3890
# code : 156464, page : 266 / 3890
# code : 156464, page : 267 / 3890
# code : 156464, page : 268 / 3890
# code : 156464, page : 269 / 3890
# code : 156464, page : 270 / 3890
# code : 156464, page : 271 / 3890
# code : 156464, page : 272 / 3890
# code : 156464, page : 273 / 3890
# code : 156464, page : 274 / 3890
# code : 156464, page : 275 / 3890
# code : 156464, page : 276 / 3890
# code : 156464, page : 277 / 3890
# code : 156464, page : 278 / 3890
# code : 156464, page : 279 / 3890
# code : 156464, page : 280 / 3890
# code : 156464, page : 281 / 3890
# code : 156464, page : 282 / 3890
# code : 156464, page : 283 / 3890
# code : 156464, page : 284 / 3890
# code : 156464, page : 285 / 3890
# code : 156464, page : 286 / 3890
# code : 156464, page : 287 / 3890
# code : 156464, page : 288 / 3890
# code : 156464, page : 289 / 3890
# code : 156464, page : 290 / 3890
# code : 156464, page : 291 / 3890
# code : 156464, page : 292 / 3890
# code : 156464, page : 293 / 3890
# code : 156464, page : 294 / 3890
# code : 156464, page : 295 / 3890
# code : 156464, page : 296 / 3890
# code : 156464, page : 297 / 3890
# code : 156464, page : 298 / 3890
# code : 156464, page : 299 / 3890
# code : 156464, page : 300 / 3890
# code : 156464, page : 301 / 3890
# code : 156464, page : 302 / 3890
# code : 156464, page : 303 / 3890
# code : 156464, page : 304 / 3890
# code : 156464, page : 305 / 3890
# code : 156464, page : 306 / 3890
# code : 156464, page : 307 / 3890
# code : 156464, page : 308 / 3890
# code : 156464, page : 309 / 3890
# code : 156464, page : 310 / 3890
# code : 156464, page : 311 / 3890
# code : 156464, page : 312 / 3890
# code : 156464, page : 313 / 3890
# code : 156464, page : 314 / 3890
# code : 156464, page : 315 / 3890
# code : 156464, page : 316 / 3890
# code : 156464, page : 317 / 3890
# code : 156464, page : 318 / 3890
# code : 156464, page : 319 / 3890
# code : 156464, page : 320 / 3890
# code : 156464, page : 321 / 3890
# code : 156464, page : 322 / 3890
# code : 156464, page : 323 / 3890
# code : 156464, page : 324 / 3890
# code : 156464, page : 325 / 3890
# code : 156464, page : 326 / 3890
# code : 156464, page : 327 / 3890
# code : 156464, page : 328 / 3890
# code : 156464, page : 329 / 3890
# code : 156464, page : 330 / 3890
# code : 156464, page : 331 / 3890
# code : 156464, page : 332 / 3890
# code : 156464, page : 333 / 3890
# code : 156464, page : 334 / 3890
# code : 156464, page : 335 / 3890
# code : 156464, page : 336 / 3890
# code : 156464, page : 337 / 3890
# code : 156464, page : 338 / 3890
# code : 156464, page : 339 / 3890
# code : 156464, page : 340 / 3890
# code : 156464, page : 341 / 3890
# code : 156464, page : 342 / 3890
# code : 156464, page : 343 / 3890
# code : 156464, page : 344 / 3890
# code : 156464, page : 345 / 3890
# code : 156464, page : 346 / 3890
# code : 156464, page : 347 / 3890
# code : 156464, page : 348 / 3890
# code : 156464, page : 349 / 3890
# code : 156464, page : 350 / 3890
# code : 156464, page : 351 / 3890
# code : 156464, page : 352 / 3890
# code : 156464, page : 353 / 3890
# code : 156464, page : 354 / 3890
# code : 156464, page : 355 / 3890
# code : 156464, page : 356 / 3890
# code : 156464, page : 357 / 3890
# code : 156464, page : 358 / 3890
# code : 156464, page : 359 / 3890
# code : 156464, page : 360 / 3890
# code : 156464, page : 361 / 3890
# code : 156464, page : 362 / 3890
# code : 156464, page : 363 / 3890
# code : 156464, page : 364 / 3890
# code : 156464, page : 365 / 3890
# code : 156464, page : 366 / 3890
# code : 156464, page : 367 / 3890
# code : 156464, page : 368 / 3890
# code : 156464, page : 369 / 3890
# code : 156464, page : 370 / 3890
# code : 156464, page : 371 / 3890
# code : 156464, page : 372 / 3890
# code : 156464, page : 373 / 3890
# code : 156464, page : 374 / 3890
# code : 156464, page : 375 / 3890
# code : 156464, page : 376 / 3890
# code : 156464, page : 377 / 3890
# code : 156464, page : 378 / 3890
# code : 156464, page : 379 / 3890
# code : 156464, page : 380 / 3890
# code : 156464, page : 381 / 3890
# code : 156464, page : 382 / 3890
# code : 156464, page : 383 / 3890
# code : 156464, page : 384 / 3890
# code : 156464, page : 385 / 3890
# code : 156464, page : 386 / 3890
# code : 156464, page : 387 / 3890
# code : 156464, page : 388 / 3890
# code : 156464, page : 389 / 3890
# code : 156464, page : 390 / 3890
# code : 156464, page : 391 / 3890
# code : 156464, page : 392 / 3890
# code : 156464, page : 393 / 3890
# code : 156464, page : 394 / 3890
# code : 156464, page : 395 / 3890
# code : 156464, page : 396 / 3890
# code : 156464, page : 397 / 3890
# code : 156464, page : 398 / 3890
# code : 156464, page : 399 / 3890
# code : 156464, page : 400 / 3890
# code : 156464, page : 401 / 3890
# code : 156464, page : 402 / 3890
# code : 156464, page : 403 / 3890
# code : 156464, page : 404 / 3890
# code : 156464, page : 405 / 3890
# code : 156464, page : 406 / 3890
# code : 156464, page : 407 / 3890
# code : 156464, page : 408 / 3890
# code : 156464, page : 409 / 3890
# code : 156464, page : 410 / 3890
# code : 156464, page : 411 / 3890
# code : 156464, page : 412 / 3890
# code : 156464, page : 413 / 3890
# code : 156464, page : 414 / 3890
# code : 156464, page : 415 / 3890
# code : 156464, page : 416 / 3890
# code : 156464, page : 417 / 3890
# code : 156464, page : 418 / 3890
# code : 156464, page : 419 / 3890
# code : 156464, page : 420 / 3890
# code : 156464, page : 421 / 3890
# code : 156464, page : 422 / 3890
# code : 156464, page : 423 / 3890
# code : 156464, page : 424 / 3890
# code : 156464, page : 425 / 3890
# code : 156464, page : 426 / 3890
# code : 156464, page : 427 / 3890
# code : 156464, page : 428 / 3890
# code : 156464, page : 429 / 3890
# code : 156464, page : 430 / 3890
# code : 156464, page : 431 / 3890
# code : 156464, page : 432 / 3890
# code : 156464, page : 433 / 3890
# code : 156464, page : 434 / 3890
# code : 156464, page : 435 / 3890
# code : 156464, page : 436 / 3890
# code : 156464, page : 437 / 3890
# code : 156464, page : 438 / 3890
# code : 156464, page : 439 / 3890
# code : 156464, page : 440 / 3890
# code : 156464, page : 441 / 3890
# code : 156464, page : 442 / 3890
# code : 156464, page : 443 / 3890
# code : 156464, page : 444 / 3890
# code : 156464, page : 445 / 3890
# code : 156464, page : 446 / 3890
# code : 156464, page : 447 / 3890
# code : 156464, page : 448 / 3890
# code : 156464, page : 449 / 3890
# code : 156464, page : 450 / 3890
# code : 156464, page : 451 / 3890
# code : 156464, page : 452 / 3890
# code : 156464, page : 453 / 3890
# code : 156464, page : 454 / 3890
# code : 156464, page : 455 / 3890
# code : 156464, page : 456 / 3890
# code : 156464, page : 457 / 3890
# code : 156464, page : 458 / 3890
# code : 156464, page : 459 / 3890
# code : 156464, page : 460 / 3890
# code : 156464, page : 461 / 3890
# code : 156464, page : 462 / 3890
# code : 156464, page : 463 / 3890
# code : 156464, page : 464 / 3890
# code : 156464, page : 465 / 3890
# code : 156464, page : 466 / 3890
# code : 156464, page : 467 / 3890
# code : 156464, page : 468 / 3890
# code : 156464, page : 469 / 3890
# code : 156464, page : 470 / 3890
# code : 156464, page : 471 / 3890
# code : 156464, page : 472 / 3890
# code : 156464, page : 473 / 3890
# code : 156464, page : 474 / 3890
# code : 156464, page : 475 / 3890
# code : 156464, page : 476 / 3890
# code : 156464, page : 477 / 3890
# code : 156464, page : 478 / 3890
# code : 156464, page : 479 / 3890
# code : 156464, page : 480 / 3890
# code : 156464, page : 481 / 3890
# code : 156464, page : 482 / 3890
# code : 156464, page : 483 / 3890
# code : 156464, page : 484 / 3890
# code : 156464, page : 485 / 3890
# code : 156464, page : 486 / 3890
# code : 156464, page : 487 / 3890
# code : 156464, page : 488 / 3890
# code : 156464, page : 489 / 3890
# code : 156464, page : 490 / 3890
# code : 156464, page : 491 / 3890
# code : 156464, page : 492 / 3890
# code : 156464, page : 493 / 3890
# code : 156464, page : 494 / 3890
# code : 156464, page : 495 / 3890
# code : 156464, page : 496 / 3890
# code : 156464, page : 497 / 3890
# code : 156464, page : 498 / 3890
# code : 156464, page : 499 / 3890
# code : 156464, page : 500 / 3890
# code : 156464, page : 501 / 3890
# code : 156464, page : 502 / 3890
# code : 156464, page : 503 / 3890
# code : 156464, page : 504 / 3890
# code : 156464, page : 505 / 3890
# code : 156464, page : 506 / 3890
# code : 156464, page : 507 / 3890
# code : 156464, page : 508 / 3890
# code : 156464, page : 509 / 3890
# code : 156464, page : 510 / 3890
# code : 156464, page : 511 / 3890
# code : 156464, page : 512 / 3890
# code : 156464, page : 513 / 3890
# code : 156464, page : 514 / 3890
# code : 156464, page : 515 / 3890
# code : 156464, page : 516 / 3890
# code : 156464, page : 517 / 3890
# code : 156464, page : 518 / 3890
# code : 156464, page : 519 / 3890
# code : 156464, page : 520 / 3890
# code : 156464, page : 521 / 3890
# code : 156464, page : 522 / 3890
# code : 156464, page : 523 / 3890
# code : 156464, page : 524 / 3890
# code : 156464, page : 525 / 3890
# code : 156464, page : 526 / 3890
# code : 156464, page : 527 / 3890
# code : 156464, page : 528 / 3890
# code : 156464, page : 529 / 3890
# code : 156464, page : 530 / 3890
# code : 156464, page : 531 / 3890
# code : 156464, page : 532 / 3890
# code : 156464, page : 533 / 3890
# code : 156464, page : 534 / 3890
# code : 156464, page : 535 / 3890
# code : 156464, page : 536 / 3890
# code : 156464, page : 537 / 3890
# code : 156464, page : 538 / 3890
# code : 156464, page : 539 / 3890
# code : 156464, page : 540 / 3890
# code : 156464, page : 541 / 3890
# code : 156464, page : 542 / 3890
# code : 156464, page : 543 / 3890
# code : 156464, page : 544 / 3890
# code : 156464, page : 545 / 3890
# code : 156464, page : 546 / 3890
# code : 156464, page : 547 / 3890
# code : 156464, page : 548 / 3890
# code : 156464, page : 549 / 3890
# code : 156464, page : 550 / 3890
# code : 156464, page : 551 / 3890
# code : 156464, page : 552 / 3890
# code : 156464, page : 553 / 3890
# code : 156464, page : 554 / 3890
# code : 156464, page : 555 / 3890
# code : 156464, page : 556 / 3890
# code : 156464, page : 557 / 3890
# code : 156464, page : 558 / 3890
# code : 156464, page : 559 / 3890
# code : 156464, page : 560 / 3890
# code : 156464, page : 561 / 3890
# code : 156464, page : 562 / 3890
# code : 156464, page : 563 / 3890
# code : 156464, page : 564 / 3890
# code : 156464, page : 565 / 3890
# code : 156464, page : 566 / 3890
# code : 156464, page : 567 / 3890
# code : 156464, page : 568 / 3890
# code : 156464, page : 569 / 3890
# code : 156464, page : 570 / 3890
# code : 156464, page : 571 / 3890
# code : 156464, page : 572 / 3890
# code : 156464, page : 573 / 3890
# code : 156464, page : 574 / 3890
# code : 156464, page : 575 / 3890
# code : 156464, page : 576 / 3890
# code : 156464, page : 577 / 3890
# code : 156464, page : 578 / 3890
# code : 156464, page : 579 / 3890
# code : 156464, page : 580 / 3890
# code : 156464, page : 581 / 3890
# code : 156464, page : 582 / 3890
# code : 156464, page : 583 / 3890
# code : 156464, page : 584 / 3890
# code : 156464, page : 585 / 3890
# code : 156464, page : 586 / 3890
# code : 156464, page : 587 / 3890
# code : 156464, page : 588 / 3890
# code : 156464, page : 589 / 3890
# code : 156464, page : 590 / 3890
# code : 156464, page : 591 / 3890
# code : 156464, page : 592 / 3890
# code : 156464, page : 593 / 3890
# code : 156464, page : 594 / 3890
# code : 156464, page : 595 / 3890
# code : 156464, page : 596 / 3890
# code : 156464, page : 597 / 3890
# code : 156464, page : 598 / 3890
# code : 156464, page : 599 / 3890
# code : 156464, page : 600 / 3890
# code : 156464, page : 601 / 3890
# code : 156464, page : 602 / 3890
# code : 156464, page : 603 / 3890
# code : 156464, page : 604 / 3890
# code : 156464, page : 605 / 3890
# code : 156464, page : 606 / 3890
# code : 156464, page : 607 / 3890
# code : 156464, page : 608 / 3890
# code : 156464, page : 609 / 3890
# code : 156464, page : 610 / 3890
# code : 156464, page : 611 / 3890
# code : 156464, page : 612 / 3890
# code : 156464, page : 613 / 3890
# code : 156464, page : 614 / 3890
# code : 156464, page : 615 / 3890
# code : 156464, page : 616 / 3890
# code : 156464, page : 617 / 3890
# code : 156464, page : 618 / 3890
# code : 156464, page : 619 / 3890
# code : 156464, page : 620 / 3890
# code : 156464, page : 621 / 3890
# code : 156464, page : 622 / 3890
# code : 156464, page : 623 / 3890
# code : 156464, page : 624 / 3890
# code : 156464, page : 625 / 3890
# code : 156464, page : 626 / 3890
# code : 156464, page : 627 / 3890
# code : 156464, page : 628 / 3890
# code : 156464, page : 629 / 3890
# code : 156464, page : 630 / 3890
# code : 156464, page : 631 / 3890
# code : 156464, page : 632 / 3890
# code : 156464, page : 633 / 3890
# code : 156464, page : 634 / 3890
# code : 156464, page : 635 / 3890
# code : 156464, page : 636 / 3890
# code : 156464, page : 637 / 3890
# code : 156464, page : 638 / 3890
# code : 156464, page : 639 / 3890
# code : 156464, page : 640 / 3890
# code : 156464, page : 641 / 3890
# code : 156464, page : 642 / 3890
# code : 156464, page : 643 / 3890
# code : 156464, page : 644 / 3890
# code : 156464, page : 645 / 3890
# code : 156464, page : 646 / 3890
# code : 156464, page : 647 / 3890
# code : 156464, page : 648 / 3890
# code : 156464, page : 649 / 3890
# code : 156464, page : 650 / 3890
# code : 156464, page : 651 / 3890
# code : 156464, page : 652 / 3890
# code : 156464, page : 653 / 3890
# code : 156464, page : 654 / 3890
# code : 156464, page : 655 / 3890
# code : 156464, page : 656 / 3890
# code : 156464, page : 657 / 3890
# code : 156464, page : 658 / 3890
# code : 156464, page : 659 / 3890
# code : 156464, page : 660 / 3890
# code : 156464, page : 661 / 3890
# code : 156464, page : 662 / 3890
# code : 156464, page : 663 / 3890
# code : 156464, page : 664 / 3890
# code : 156464, page : 665 / 3890
# code : 156464, page : 666 / 3890
# code : 156464, page : 667 / 3890
# code : 156464, page : 668 / 3890
# code : 156464, page : 669 / 3890
# code : 156464, page : 670 / 3890
# code : 156464, page : 671 / 3890
# code : 156464, page : 672 / 3890
# code : 156464, page : 673 / 3890
# code : 156464, page : 674 / 3890
# code : 156464, page : 675 / 3890
# code : 156464, page : 676 / 3890
# code : 156464, page : 677 / 3890
# code : 156464, page : 678 / 3890
# code : 156464, page : 679 / 3890
# code : 156464, page : 680 / 3890
# code : 156464, page : 681 / 3890
# code : 156464, page : 682 / 3890
# code : 156464, page : 683 / 3890
# code : 156464, page : 684 / 3890
# code : 156464, page : 685 / 3890
# code : 156464, page : 686 / 3890
# code : 156464, page : 687 / 3890
# code : 156464, page : 688 / 3890
# code : 156464, page : 689 / 3890
# code : 156464, page : 690 / 3890
# code : 156464, page : 691 / 3890
# code : 156464, page : 692 / 3890
# code : 156464, page : 693 / 3890
# code : 156464, page : 694 / 3890
# code : 156464, page : 695 / 3890
# code : 156464, page : 696 / 3890
# code : 156464, page : 697 / 3890
# code : 156464, page : 698 / 3890
# code : 156464, page : 699 / 3890
# code : 156464, page : 700 / 3890
# code : 156464, page : 701 / 3890
# code : 156464, page : 702 / 3890
# code : 156464, page : 703 / 3890
# code : 156464, page : 704 / 3890
# code : 156464, page : 705 / 3890
# code : 156464, page : 706 / 3890
# code : 156464, page : 707 / 3890
# code : 156464, page : 708 / 3890
# code : 156464, page : 709 / 3890
# code : 156464, page : 710 / 3890
# code : 156464, page : 711 / 3890
# code : 156464, page : 712 / 3890
# code : 156464, page : 713 / 3890
# code : 156464, page : 714 / 3890
# code : 156464, page : 715 / 3890
# code : 156464, page : 716 / 3890
# code : 156464, page : 717 / 3890
# code : 156464, page : 718 / 3890
# code : 156464, page : 719 / 3890
# code : 156464, page : 720 / 3890
# code : 156464, page : 721 / 3890
# code : 156464, page : 722 / 3890
# code : 156464, page : 723 / 3890
# code : 156464, page : 724 / 3890
# code : 156464, page : 725 / 3890
# code : 156464, page : 726 / 3890
# code : 156464, page : 727 / 3890
# code : 156464, page : 728 / 3890
# code : 156464, page : 729 / 3890
# code : 156464, page : 730 / 3890
# code : 156464, page : 731 / 3890
# code : 156464, page : 732 / 3890
# code : 156464, page : 733 / 3890
# code : 156464, page : 734 / 3890
# code : 156464, page : 735 / 3890
# code : 156464, page : 736 / 3890
# code : 156464, page : 737 / 3890
# code : 156464, page : 738 / 3890
# code : 156464, page : 739 / 3890
# code : 156464, page : 740 / 3890
# code : 156464, page : 741 / 3890
# code : 156464, page : 742 / 3890
# code : 156464, page : 743 / 3890
# code : 156464, page : 744 / 3890
# code : 156464, page : 745 / 3890
# code : 156464, page : 746 / 3890
# code : 156464, page : 747 / 3890
# code : 156464, page : 748 / 3890
# code : 156464, page : 749 / 3890
# code : 156464, page : 750 / 3890
# code : 156464, page : 751 / 3890
# code : 156464, page : 752 / 3890
# code : 156464, page : 753 / 3890
# code : 156464, page : 754 / 3890
# code : 156464, page : 755 / 3890
# code : 156464, page : 756 / 3890
# code : 156464, page : 757 / 3890
# code : 156464, page : 758 / 3890
# code : 156464, page : 759 / 3890
# code : 156464, page : 760 / 3890
# code : 156464, page : 761 / 3890
# code : 156464, page : 762 / 3890
# code : 156464, page : 763 / 3890
# code : 156464, page : 764 / 3890
# code : 156464, page : 765 / 3890
# code : 156464, page : 766 / 3890
# code : 156464, page : 767 / 3890
# code : 156464, page : 768 / 3890
# code : 156464, page : 769 / 3890
# code : 156464, page : 770 / 3890
# code : 156464, page : 771 / 3890
# code : 156464, page : 772 / 3890
# code : 156464, page : 773 / 3890
# code : 156464, page : 774 / 3890
# code : 156464, page : 775 / 3890
# code : 156464, page : 776 / 3890
# code : 156464, page : 777 / 3890
# code : 156464, page : 778 / 3890
# code : 156464, page : 779 / 3890
# code : 156464, page : 780 / 3890
# code : 156464, page : 781 / 3890
# code : 156464, page : 782 / 3890
# code : 156464, page : 783 / 3890
# code : 156464, page : 784 / 3890
# code : 156464, page : 785 / 3890
# code : 156464, page : 786 / 3890
# code : 156464, page : 787 / 3890
# code : 156464, page : 788 / 3890
# code : 156464, page : 789 / 3890
# code : 156464, page : 790 / 3890
# code : 156464, page : 791 / 3890
# code : 156464, page : 792 / 3890
# code : 156464, page : 793 / 3890
# code : 156464, page : 794 / 3890
# code : 156464, page : 795 / 3890
# code : 156464, page : 796 / 3890
# code : 156464, page : 797 / 3890
# code : 156464, page : 798 / 3890
# code : 156464, page : 799 / 3890
# code : 156464, page : 800 / 3890
# code : 156464, page : 801 / 3890
# code : 156464, page : 802 / 3890
# code : 156464, page : 803 / 3890
# code : 156464, page : 804 / 3890
# code : 156464, page : 805 / 3890
# code : 156464, page : 806 / 3890
# code : 156464, page : 807 / 3890
# code : 156464, page : 808 / 3890
# code : 156464, page : 809 / 3890
# code : 156464, page : 810 / 3890
# code : 156464, page : 811 / 3890
# code : 156464, page : 812 / 3890
# code : 156464, page : 813 / 3890
# code : 156464, page : 814 / 3890
# code : 156464, page : 815 / 3890
# code : 156464, page : 816 / 3890
# code : 156464, page : 817 / 3890
# code : 156464, page : 818 / 3890
# code : 156464, page : 819 / 3890
# code : 156464, page : 820 / 3890
# code : 156464, page : 821 / 3890
# code : 156464, page : 822 / 3890
# code : 156464, page : 823 / 3890
# code : 156464, page : 824 / 3890
# code : 156464, page : 825 / 3890
# code : 156464, page : 826 / 3890
# code : 156464, page : 827 / 3890
# code : 156464, page : 828 / 3890
# code : 156464, page : 829 / 3890
# code : 156464, page : 830 / 3890
# code : 156464, page : 831 / 3890
# code : 156464, page : 832 / 3890
# code : 156464, page : 833 / 3890
# code : 156464, page : 834 / 3890
# code : 156464, page : 835 / 3890
# code : 156464, page : 836 / 3890
# code : 156464, page : 837 / 3890
# code : 156464, page : 838 / 3890
# code : 156464, page : 839 / 3890
# code : 156464, page : 840 / 3890
# code : 156464, page : 841 / 3890
# code : 156464, page : 842 / 3890
# code : 156464, page : 843 / 3890
# code : 156464, page : 844 / 3890
# code : 156464, page : 845 / 3890
# code : 156464, page : 846 / 3890
# code : 156464, page : 847 / 3890
# code : 156464, page : 848 / 3890
# code : 156464, page : 849 / 3890
# code : 156464, page : 850 / 3890
# code : 156464, page : 851 / 3890
# code : 156464, page : 852 / 3890
# code : 156464, page : 853 / 3890
# code : 156464, page : 854 / 3890
# code : 156464, page : 855 / 3890
# code : 156464, page : 856 / 3890
# code : 156464, page : 857 / 3890
# code : 156464, page : 858 / 3890
# code : 156464, page : 859 / 3890
# code : 156464, page : 860 / 3890
# code : 156464, page : 861 / 3890
# code : 156464, page : 862 / 3890
# code : 156464, page : 863 / 3890
# code : 156464, page : 864 / 3890
# code : 156464, page : 865 / 3890
# code : 156464, page : 866 / 3890
# code : 156464, page : 867 / 3890
# code : 156464, page : 868 / 3890
# code : 156464, page : 869 / 3890
# code : 156464, page : 870 / 3890
# code : 156464, page : 871 / 3890
# code : 156464, page : 872 / 3890
# code : 156464, page : 873 / 3890
# code : 156464, page : 874 / 3890
# code : 156464, page : 875 / 3890
# code : 156464, page : 876 / 3890
# code : 156464, page : 877 / 3890
# code : 156464, page : 878 / 3890
# code : 156464, page : 879 / 3890
# code : 156464, page : 880 / 3890
# code : 156464, page : 881 / 3890
# code : 156464, page : 882 / 3890
# code : 156464, page : 883 / 3890
# code : 156464, page : 884 / 3890
# code : 156464, page : 885 / 3890
# code : 156464, page : 886 / 3890
# code : 156464, page : 887 / 3890
# code : 156464, page : 888 / 3890
# code : 156464, page : 889 / 3890
# code : 156464, page : 890 / 3890
# code : 156464, page : 891 / 3890
# code : 156464, page : 892 / 3890
# code : 156464, page : 893 / 3890
# code : 156464, page : 894 / 3890
# code : 156464, page : 895 / 3890
# code : 156464, page : 896 / 3890
# code : 156464, page : 897 / 3890
# code : 156464, page : 898 / 3890
# code : 156464, page : 899 / 3890
# code : 156464, page : 900 / 3890
# code : 156464, page : 901 / 3890
# code : 156464, page : 902 / 3890
# code : 156464, page : 903 / 3890
# code : 156464, page : 904 / 3890
# code : 156464, page : 905 / 3890
# code : 156464, page : 906 / 3890
# code : 156464, page : 907 / 3890
# code : 156464, page : 908 / 3890
# code : 156464, page : 909 / 3890
# code : 156464, page : 910 / 3890
# code : 156464, page : 911 / 3890
# code : 156464, page : 912 / 3890
# code : 156464, page : 913 / 3890
# code : 156464, page : 914 / 3890
# code : 156464, page : 915 / 3890
# code : 156464, page : 916 / 3890
# code : 156464, page : 917 / 3890
# code : 156464, page : 918 / 3890
# code : 156464, page : 919 / 3890
# code : 156464, page : 920 / 3890
# code : 156464, page : 921 / 3890
# code : 156464, page : 922 / 3890
# code : 156464, page : 923 / 3890
# code : 156464, page : 924 / 3890
# code : 156464, page : 925 / 3890
# code : 156464, page : 926 / 3890
# code : 156464, page : 927 / 3890
# code : 156464, page : 928 / 3890
# code : 156464, page : 929 / 3890
# code : 156464, page : 930 / 3890
# code : 156464, page : 931 / 3890
# code : 156464, page : 932 / 3890
# code : 156464, page : 933 / 3890
# code : 156464, page : 934 / 3890
# code : 156464, page : 935 / 3890
# code : 156464, page : 936 / 3890
# code : 156464, page : 937 / 3890
# code : 156464, page : 938 / 3890
# code : 156464, page : 939 / 3890
# code : 156464, page : 940 / 3890
# code : 156464, page : 941 / 3890
# code : 156464, page : 942 / 3890
# code : 156464, page : 943 / 3890
# code : 156464, page : 944 / 3890
# code : 156464, page : 945 / 3890
# code : 156464, page : 946 / 3890
# code : 156464, page : 947 / 3890
# code : 156464, page : 948 / 3890
# code : 156464, page : 949 / 3890
# code : 156464, page : 950 / 3890
# code : 156464, page : 951 / 3890
# code : 156464, page : 952 / 3890
# code : 156464, page : 953 / 3890
# code : 156464, page : 954 / 3890
# code : 156464, page : 955 / 3890
# code : 156464, page : 956 / 3890
# code : 156464, page : 957 / 3890
# code : 156464, page : 958 / 3890
# code : 156464, page : 959 / 3890
# code : 156464, page : 960 / 3890
# code : 156464, page : 961 / 3890
# code : 156464, page : 962 / 3890
# code : 156464, page : 963 / 3890
# code : 156464, page : 964 / 3890
# code : 156464, page : 965 / 3890
# code : 156464, page : 966 / 3890
# code : 156464, page : 967 / 3890
# code : 156464, page : 968 / 3890
# code : 156464, page : 969 / 3890
# code : 156464, page : 970 / 3890
# code : 156464, page : 971 / 3890
# code : 156464, page : 972 / 3890
# code : 156464, page : 973 / 3890
# code : 156464, page : 974 / 3890
# code : 156464, page : 975 / 3890
# code : 156464, page : 976 / 3890
# code : 156464, page : 977 / 3890
# code : 156464, page : 978 / 3890
# code : 156464, page : 979 / 3890
# code : 156464, page : 980 / 3890
# code : 156464, page : 981 / 3890
# code : 156464, page : 982 / 3890
# code : 156464, page : 983 / 3890
# code : 156464, page : 984 / 3890
# code : 156464, page : 985 / 3890
# code : 156464, page : 986 / 3890
# code : 156464, page : 987 / 3890
# code : 156464, page : 988 / 3890
# code : 156464, page : 989 / 3890
# code : 156464, page : 990 / 3890
# code : 156464, page : 991 / 3890
# code : 156464, page : 992 / 3890
# code : 156464, page : 993 / 3890
# code : 156464, page : 994 / 3890
# code : 156464, page : 995 / 3890
# code : 156464, page : 996 / 3890
# code : 156464, page : 997 / 3890
# code : 156464, page : 998 / 3890
# code : 156464, page : 999 / 3890
# code : 156464, page : 1000 / 3890
# code : 156464, page : 1001 / 3890
# code : 156464, page : 1002 / 3890
# code : 156464, page : 1003 / 3890
# code : 156464, page : 1004 / 3890
# code : 156464, page : 1005 / 3890
# code : 156464, page : 1006 / 3890
# code : 156464, page : 1007 / 3890
# code : 156464, page : 1008 / 3890
# code : 156464, page : 1009 / 3890
# code : 156464, page : 1010 / 3890
# code : 156464, page : 1011 / 3890
# code : 156464, page : 1012 / 3890
# code : 156464, page : 1013 / 3890
# code : 156464, page : 1014 / 3890
# code : 156464, page : 1015 / 3890
# code : 156464, page : 1016 / 3890
# code : 156464, page : 1017 / 3890
# code : 156464, page : 1018 / 3890
# code : 156464, page : 1019 / 3890
# code : 156464, page : 1020 / 3890
# code : 156464, page : 1021 / 3890
# code : 156464, page : 1022 / 3890
# code : 156464, page : 1023 / 3890
# code : 156464, page : 1024 / 3890
# code : 156464, page : 1025 / 3890
# code : 156464, page : 1026 / 3890
# code : 156464, page : 1027 / 3890
# code : 156464, page : 1028 / 3890
# code : 156464, page : 1029 / 3890
# code : 156464, page : 1030 / 3890
# code : 156464, page : 1031 / 3890
# code : 156464, page : 1032 / 3890
# code : 156464, page : 1033 / 3890
# code : 156464, page : 1034 / 3890
# code : 156464, page : 1035 / 3890
# code : 156464, page : 1036 / 3890
# code : 156464, page : 1037 / 3890
# code : 156464, page : 1038 / 3890
# code : 156464, page : 1039 / 3890
# code : 156464, page : 1040 / 3890
# code : 156464, page : 1041 / 3890
# code : 156464, page : 1042 / 3890
# code : 156464, page : 1043 / 3890
# code : 156464, page : 1044 / 3890
# code : 156464, page : 1045 / 3890
# code : 156464, page : 1046 / 3890
# code : 156464, page : 1047 / 3890
# code : 156464, page : 1048 / 3890
# code : 156464, page : 1049 / 3890
# code : 156464, page : 1050 / 3890
# code : 156464, page : 1051 / 3890
# code : 156464, page : 1052 / 3890
# code : 156464, page : 1053 / 3890
# code : 156464, page : 1054 / 3890
# code : 156464, page : 1055 / 3890
# code : 156464, page : 1056 / 3890
# code : 156464, page : 1057 / 3890
# code : 156464, page : 1058 / 3890
# code : 156464, page : 1059 / 3890
# code : 156464, page : 1060 / 3890
# code : 156464, page : 1061 / 3890
# code : 156464, page : 1062 / 3890
# code : 156464, page : 1063 / 3890
# code : 156464, page : 1064 / 3890
# code : 156464, page : 1065 / 3890
# code : 156464, page : 1066 / 3890
# code : 156464, page : 1067 / 3890
# code : 156464, page : 1068 / 3890
# code : 156464, page : 1069 / 3890
# code : 156464, page : 1070 / 3890
# code : 156464, page : 1071 / 3890
# code : 156464, page : 1072 / 3890
# code : 156464, page : 1073 / 3890
# code : 156464, page : 1074 / 3890
# code : 156464, page : 1075 / 3890
# code : 156464, page : 1076 / 3890
# code : 156464, page : 1077 / 3890
# code : 156464, page : 1078 / 3890
# code : 156464, page : 1079 / 3890
# code : 156464, page : 1080 / 3890
# code : 156464, page : 1081 / 3890
# code : 156464, page : 1082 / 3890
# code : 156464, page : 1083 / 3890
# code : 156464, page : 1084 / 3890
# code : 156464, page : 1085 / 3890
# code : 156464, page : 1086 / 3890
# code : 156464, page : 1087 / 3890
# code : 156464, page : 1088 / 3890
# code : 156464, page : 1089 / 3890
# code : 156464, page : 1090 / 3890
# code : 156464, page : 1091 / 3890
# code : 156464, page : 1092 / 3890
# code : 156464, page : 1093 / 3890
# code : 156464, page : 1094 / 3890
# code : 156464, page : 1095 / 3890
# code : 156464, page : 1096 / 3890
# code : 156464, page : 1097 / 3890
# code : 156464, page : 1098 / 3890
# code : 156464, page : 1099 / 3890
# code : 156464, page : 1100 / 3890
# code : 156464, page : 1101 / 3890
# code : 156464, page : 1102 / 3890
# code : 156464, page : 1103 / 3890
# code : 156464, page : 1104 / 3890
# code : 156464, page : 1105 / 3890
# code : 156464, page : 1106 / 3890
# code : 156464, page : 1107 / 3890
# code : 156464, page : 1108 / 3890
# code : 156464, page : 1109 / 3890
# code : 156464, page : 1110 / 3890
# code : 156464, page : 1111 / 3890
# code : 156464, page : 1112 / 3890
# code : 156464, page : 1113 / 3890
# code : 156464, page : 1114 / 3890
# code : 156464, page : 1115 / 3890
# code : 156464, page : 1116 / 3890
# code : 156464, page : 1117 / 3890
# code : 156464, page : 1118 / 3890
# code : 156464, page : 1119 / 3890
# code : 156464, page : 1120 / 3890
# code : 156464, page : 1121 / 3890
# code : 156464, page : 1122 / 3890
# code : 156464, page : 1123 / 3890
# code : 156464, page : 1124 / 3890
# code : 156464, page : 1125 / 3890
# code : 156464, page : 1126 / 3890
# code : 156464, page : 1127 / 3890
# code : 156464, page : 1128 / 3890
# code : 156464, page : 1129 / 3890
# code : 156464, page : 1130 / 3890
# code : 156464, page : 1131 / 3890
# code : 156464, page : 1132 / 3890
# code : 156464, page : 1133 / 3890
# code : 156464, page : 1134 / 3890
# code : 156464, page : 1135 / 3890
# code : 156464, page : 1136 / 3890
# code : 156464, page : 1137 / 3890
# code : 156464, page : 1138 / 3890
# code : 156464, page : 1139 / 3890
# code : 156464, page : 1140 / 3890
# code : 156464, page : 1141 / 3890
# code : 156464, page : 1142 / 3890
# code : 156464, page : 1143 / 3890
# code : 156464, page : 1144 / 3890
# code : 156464, page : 1145 / 3890
# code : 156464, page : 1146 / 3890
# code : 156464, page : 1147 / 3890
# code : 156464, page : 1148 / 3890
# code : 156464, page : 1149 / 3890
# code : 156464, page : 1150 / 3890
# code : 156464, page : 1151 / 3890
# code : 156464, page : 1152 / 3890
# code : 156464, page : 1153 / 3890
# code : 156464, page : 1154 / 3890
# code : 156464, page : 1155 / 3890
# code : 156464, page : 1156 / 3890
# code : 156464, page : 1157 / 3890
# code : 156464, page : 1158 / 3890
# code : 156464, page : 1159 / 3890
# code : 156464, page : 1160 / 3890
# code : 156464, page : 1161 / 3890
# code : 156464, page : 1162 / 3890
# code : 156464, page : 1163 / 3890
# code : 156464, page : 1164 / 3890
# code : 156464, page : 1165 / 3890
# code : 156464, page : 1166 / 3890
# code : 156464, page : 1167 / 3890
# code : 156464, page : 1168 / 3890
# code : 156464, page : 1169 / 3890
# code : 156464, page : 1170 / 3890
# code : 156464, page : 1171 / 3890
# code : 156464, page : 1172 / 3890
# code : 156464, page : 1173 / 3890
# code : 156464, page : 1174 / 3890
# code : 156464, page : 1175 / 3890
# code : 156464, page : 1176 / 3890
# code : 156464, page : 1177 / 3890
# code : 156464, page : 1178 / 3890
# code : 156464, page : 1179 / 3890
# code : 156464, page : 1180 / 3890
# code : 156464, page : 1181 / 3890
# code : 156464, page : 1182 / 3890
# code : 156464, page : 1183 / 3890
# code : 156464, page : 1184 / 3890
# code : 156464, page : 1185 / 3890
# code : 156464, page : 1186 / 3890
# code : 156464, page : 1187 / 3890
# code : 156464, page : 1188 / 3890
# code : 156464, page : 1189 / 3890
# code : 156464, page : 1190 / 3890
# code : 156464, page : 1191 / 3890
# code : 156464, page : 1192 / 3890
# code : 156464, page : 1193 / 3890
# code : 156464, page : 1194 / 3890
# code : 156464, page : 1195 / 3890
# code : 156464, page : 1196 / 3890
# code : 156464, page : 1197 / 3890
# code : 156464, page : 1198 / 3890
# code : 156464, page : 1199 / 3890
# code : 156464, page : 1200 / 3890
# code : 156464, page : 1201 / 3890
# code : 156464, page : 1202 / 3890
# code : 156464, page : 1203 / 3890
# code : 156464, page : 1204 / 3890
# code : 156464, page : 1205 / 3890
# code : 156464, page : 1206 / 3890
# code : 156464, page : 1207 / 3890
# code : 156464, page : 1208 / 3890
# code : 156464, page : 1209 / 3890
# code : 156464, page : 1210 / 3890
# code : 156464, page : 1211 / 3890
# code : 156464, page : 1212 / 3890
# code : 156464, page : 1213 / 3890
# code : 156464, page : 1214 / 3890
# code : 156464, page : 1215 / 3890
# code : 156464, page : 1216 / 3890
# code : 156464, page : 1217 / 3890
# code : 156464, page : 1218 / 3890
# code : 156464, page : 1219 / 3890
# code : 156464, page : 1220 / 3890
# code : 156464, page : 1221 / 3890
# code : 156464, page : 1222 / 3890
# code : 156464, page : 1223 / 3890
# code : 156464, page : 1224 / 3890
# code : 156464, page : 1225 / 3890
# code : 156464, page : 1226 / 3890
# code : 156464, page : 1227 / 3890
# code : 156464, page : 1228 / 3890
# code : 156464, page : 1229 / 3890
# code : 156464, page : 1230 / 3890
# code : 156464, page : 1231 / 3890
# code : 156464, page : 1232 / 3890
# code : 156464, page : 1233 / 3890
# code : 156464, page : 1234 / 3890
# code : 156464, page : 1235 / 3890
# code : 156464, page : 1236 / 3890
# code : 156464, page : 1237 / 3890
# code : 156464, page : 1238 / 3890
# code : 156464, page : 1239 / 3890
# code : 156464, page : 1240 / 3890
# code : 156464, page : 1241 / 3890
# code : 156464, page : 1242 / 3890
# code : 156464, page : 1243 / 3890
# code : 156464, page : 1244 / 3890
# code : 156464, page : 1245 / 3890
# code : 156464, page : 1246 / 3890
# code : 156464, page : 1247 / 3890
# code : 156464, page : 1248 / 3890
# code : 156464, page : 1249 / 3890
# code : 156464, page : 1250 / 3890
# code : 156464, page : 1251 / 3890
# code : 156464, page : 1252 / 3890
# code : 156464, page : 1253 / 3890
# code : 156464, page : 1254 / 3890
# code : 156464, page : 1255 / 3890
# code : 156464, page : 1256 / 3890
# code : 156464, page : 1257 / 3890
# code : 156464, page : 1258 / 3890
# code : 156464, page : 1259 / 3890
# code : 156464, page : 1260 / 3890
# code : 156464, page : 1261 / 3890
# code : 156464, page : 1262 / 3890
# code : 156464, page : 1263 / 3890
# code : 156464, page : 1264 / 3890
# code : 156464, page : 1265 / 3890
# code : 156464, page : 1266 / 3890
# code : 156464, page : 1267 / 3890
# code : 156464, page : 1268 / 3890
# code : 156464, page : 1269 / 3890
# code : 156464, page : 1270 / 3890
# code : 156464, page : 1271 / 3890
# code : 156464, page : 1272 / 3890
# code : 156464, page : 1273 / 3890
# code : 156464, page : 1274 / 3890
# code : 156464, page : 1275 / 3890
# code : 156464, page : 1276 / 3890
# code : 156464, page : 1277 / 3890
# code : 156464, page : 1278 / 3890
# code : 156464, page : 1279 / 3890
# code : 156464, page : 1280 / 3890
# code : 156464, page : 1281 / 3890
# code : 156464, page : 1282 / 3890
# code : 156464, page : 1283 / 3890
# code : 156464, page : 1284 / 3890
# code : 156464, page : 1285 / 3890
# code : 156464, page : 1286 / 3890
# code : 156464, page : 1287 / 3890
# code : 156464, page : 1288 / 3890
# code : 156464, page : 1289 / 3890
# code : 156464, page : 1290 / 3890
# code : 156464, page : 1291 / 3890
# code : 156464, page : 1292 / 3890
# code : 156464, page : 1293 / 3890
# code : 156464, page : 1294 / 3890
# code : 156464, page : 1295 / 3890
# code : 156464, page : 1296 / 3890
# code : 156464, page : 1297 / 3890
# code : 156464, page : 1298 / 3890
# code : 156464, page : 1299 / 3890
# code : 156464, page : 1300 / 3890
# code : 156464, page : 1301 / 3890
# code : 156464, page : 1302 / 3890
# code : 156464, page : 1303 / 3890
# code : 156464, page : 1304 / 3890
# code : 156464, page : 1305 / 3890
# code : 156464, page : 1306 / 3890
# code : 156464, page : 1307 / 3890
# code : 156464, page : 1308 / 3890
# code : 156464, page : 1309 / 3890
# code : 156464, page : 1310 / 3890
# code : 156464, page : 1311 / 3890
# code : 156464, page : 1312 / 3890
# code : 156464, page : 1313 / 3890
# code : 156464, page : 1314 / 3890
# code : 156464, page : 1315 / 3890
# code : 156464, page : 1316 / 3890
# code : 156464, page : 1317 / 3890
# code : 156464, page : 1318 / 3890
# code : 156464, page : 1319 / 3890
# code : 156464, page : 1320 / 3890
# code : 156464, page : 1321 / 3890
# code : 156464, page : 1322 / 3890
# code : 156464, page : 1323 / 3890
# code : 156464, page : 1324 / 3890
# code : 156464, page : 1325 / 3890
# code : 156464, page : 1326 / 3890
# code : 156464, page : 1327 / 3890
# code : 156464, page : 1328 / 3890
# code : 156464, page : 1329 / 3890
# code : 156464, page : 1330 / 3890
# code : 156464, page : 1331 / 3890
# code : 156464, page : 1332 / 3890
# code : 156464, page : 1333 / 3890
# code : 156464, page : 1334 / 3890
# code : 156464, page : 1335 / 3890
# code : 156464, page : 1336 / 3890
# code : 156464, page : 1337 / 3890
# code : 156464, page : 1338 / 3890
# code : 156464, page : 1339 / 3890
# code : 156464, page : 1340 / 3890
# code : 156464, page : 1341 / 3890
# code : 156464, page : 1342 / 3890
# code : 156464, page : 1343 / 3890
# code : 156464, page : 1344 / 3890
# code : 156464, page : 1345 / 3890
# code : 156464, page : 1346 / 3890
# code : 156464, page : 1347 / 3890
# code : 156464, page : 1348 / 3890
# code : 156464, page : 1349 / 3890
# code : 156464, page : 1350 / 3890
# code : 156464, page : 1351 / 3890
# code : 156464, page : 1352 / 3890
# code : 156464, page : 1353 / 3890
# code : 156464, page : 1354 / 3890
# code : 156464, page : 1355 / 3890
# code : 156464, page : 1356 / 3890
# code : 156464, page : 1357 / 3890
# code : 156464, page : 1358 / 3890
# code : 156464, page : 1359 / 3890
# code : 156464, page : 1360 / 3890
# code : 156464, page : 1361 / 3890
# code : 156464, page : 1362 / 3890
# code : 156464, page : 1363 / 3890
# code : 156464, page : 1364 / 3890
# code : 156464, page : 1365 / 3890
# code : 156464, page : 1366 / 3890
# code : 156464, page : 1367 / 3890
# code : 156464, page : 1368 / 3890
# code : 156464, page : 1369 / 3890
# code : 156464, page : 1370 / 3890
# code : 156464, page : 1371 / 3890
# code : 156464, page : 1372 / 3890
# code : 156464, page : 1373 / 3890
# code : 156464, page : 1374 / 3890
# code : 156464, page : 1375 / 3890
# code : 156464, page : 1376 / 3890
# code : 156464, page : 1377 / 3890
# code : 156464, page : 1378 / 3890
# code : 156464, page : 1379 / 3890
# code : 156464, page : 1380 / 3890
# code : 156464, page : 1381 / 3890
# code : 156464, page : 1382 / 3890
# code : 156464, page : 1383 / 3890
# code : 156464, page : 1384 / 3890
# code : 156464, page : 1385 / 3890
# code : 156464, page : 1386 / 3890
# code : 156464, page : 1387 / 3890
# code : 156464, page : 1388 / 3890
# code : 156464, page : 1389 / 3890
# code : 156464, page : 1390 / 3890
# code : 156464, page : 1391 / 3890
# code : 156464, page : 1392 / 3890
# code : 156464, page : 1393 / 3890
# code : 156464, page : 1394 / 3890
# code : 156464, page : 1395 / 3890
# code : 156464, page : 1396 / 3890
# code : 156464, page : 1397 / 3890
# code : 156464, page : 1398 / 3890
# code : 156464, page : 1399 / 3890
# code : 156464, page : 1400 / 3890
# code : 156464, page : 1401 / 3890
# code : 156464, page : 1402 / 3890
# code : 156464, page : 1403 / 3890
# code : 156464, page : 1404 / 3890
# code : 156464, page : 1405 / 3890
# code : 156464, page : 1406 / 3890
# code : 156464, page : 1407 / 3890
# code : 156464, page : 1408 / 3890
# code : 156464, page : 1409 / 3890
# code : 156464, page : 1410 / 3890
# code : 156464, page : 1411 / 3890
# code : 156464, page : 1412 / 3890
# code : 156464, page : 1413 / 3890
# code : 156464, page : 1414 / 3890
# code : 156464, page : 1415 / 3890
# code : 156464, page : 1416 / 3890
# code : 156464, page : 1417 / 3890
# code : 156464, page : 1418 / 3890
# code : 156464, page : 1419 / 3890
# code : 156464, page : 1420 / 3890
# code : 156464, page : 1421 / 3890
# code : 156464, page : 1422 / 3890
# code : 156464, page : 1423 / 3890
# code : 156464, page : 1424 / 3890
# code : 156464, page : 1425 / 3890
# code : 156464, page : 1426 / 3890
# code : 156464, page : 1427 / 3890
# code : 156464, page : 1428 / 3890
# code : 156464, page : 1429 / 3890
# code : 156464, page : 1430 / 3890
# code : 156464, page : 1431 / 3890
# code : 156464, page : 1432 / 3890
# code : 156464, page : 1433 / 3890
# code : 156464, page : 1434 / 3890
# code : 156464, page : 1435 / 3890
# code : 156464, page : 1436 / 3890
# code : 156464, page : 1437 / 3890
# code : 156464, page : 1438 / 3890
# code : 156464, page : 1439 / 3890
# code : 156464, page : 1440 / 3890
# code : 156464, page : 1441 / 3890
# code : 156464, page : 1442 / 3890
# code : 156464, page : 1443 / 3890
# code : 156464, page : 1444 / 3890
# ...
# code : 156464, page : 3421 / 3890
# code : 156464, page : 3422 / 3890
# code : 156464, page : 3423 / 3890
# code : 156464, page : 3424 / 3890
# code : 156464, page : 3425 / 3890
# code : 156464, page : 3426 / 3890
# code : 156464, page : 3427 / 3890
# code : 156464, page : 3428 / 3890
# code : 156464, page : 3429 / 3890
# code : 156464, page : 3430 / 3890
# code : 156464, page : 3431 / 3890
# code : 156464, page : 3432 / 3890
# code : 156464, page : 3433 / 3890
# code : 156464, page : 3434 / 3890
# code : 156464, page : 3435 / 3890
# code : 156464, page : 3436 / 3890
# code : 156464, page : 3437 / 3890
# code : 156464, page : 3438 / 3890
# code : 156464, page : 3439 / 3890
# code : 156464, page : 3440 / 3890
# code : 156464, page : 3441 / 3890
# code : 156464, page : 3442 / 3890
# code : 156464, page : 3443 / 3890
# code : 156464, page : 3444 / 3890
# code : 156464, page : 3445 / 3890
# code : 156464, page : 3446 / 3890
# code : 156464, page : 3447 / 3890
# code : 156464, page : 3448 / 3890
# code : 156464, page : 3449 / 3890
# code : 156464, page : 3450 / 3890
# code : 156464, page : 3451 / 3890
# code : 156464, page : 3452 / 3890
# code : 156464, page : 3453 / 3890
# code : 156464, page : 3454 / 3890
# code : 156464, page : 3455 / 3890
# code : 156464, page : 3456 / 3890
# code : 156464, page : 3457 / 3890
# code : 156464, page : 3458 / 3890
# code : 156464, page : 3459 / 3890
# code : 156464, page : 3460 / 3890
# code : 156464, page : 3461 / 3890
# code : 156464, page : 3462 / 3890
# code : 156464, page : 3463 / 3890
# code : 156464, page : 3464 / 3890
# code : 156464, page : 3465 / 3890
# code : 156464, page : 3466 / 3890
# code : 156464, page : 3467 / 3890
# code : 156464, page : 3468 / 3890
# code : 156464, page : 3469 / 3890
# code : 156464, page : 3470 / 3890
# code : 156464, page : 3471 / 3890
# code : 156464, page : 3472 / 3890
# code : 156464, page : 3473 / 3890
# code : 156464, page : 3474 / 3890
# code : 156464, page : 3475 / 3890
# code : 156464, page : 3476 / 3890
# code : 156464, page : 3477 / 3890
# code : 156464, page : 3478 / 3890
# code : 156464, page : 3479 / 3890
# code : 156464, page : 3480 / 3890
# code : 156464, page : 3481 / 3890
# code : 156464, page : 3482 / 3890
# code : 156464, page : 3483 / 3890
# code : 156464, page : 3484 / 3890
# code : 156464, page : 3485 / 3890
# code : 156464, page : 3486 / 3890
# code : 156464, page : 3487 / 3890
# code : 156464, page : 3488 / 3890
# code : 156464, page : 3489 / 3890
# code : 156464, page : 3490 / 3890
# code : 156464, page : 3491 / 3890
# code : 156464, page : 3492 / 3890
# code : 156464, page : 3493 / 3890
# code : 156464, page : 3494 / 3890
# code : 156464, page : 3495 / 3890
# code : 156464, page : 3496 / 3890
# code : 156464, page : 3497 / 3890
# code : 156464, page : 3498 / 3890
# code : 156464, page : 3499 / 3890
# code : 156464, page : 3500 / 3890
# code : 156464, page : 3501 / 3890
# code : 156464, page : 3502 / 3890
# code : 156464, page : 3503 / 3890
# code : 156464, page : 3504 / 3890
# code : 156464, page : 3505 / 3890
# code : 156464, page : 3506 / 3890
# code : 156464, page : 3507 / 3890
# code : 156464, page : 3508 / 3890
# code : 156464, page : 3509 / 3890
# code : 156464, page : 3510 / 3890
# code : 156464, page : 3511 / 3890
# code : 156464, page : 3512 / 3890
# code : 156464, page : 3513 / 3890
# code : 156464, page : 3514 / 3890
# code : 156464, page : 3515 / 3890
# code : 156464, page : 3516 / 3890
# code : 156464, page : 3517 / 3890
# code : 156464, page : 3518 / 3890
# code : 156464, page : 3519 / 3890
# code : 156464, page : 3520 / 3890
# code : 156464, page : 3521 / 3890
# code : 156464, page : 3522 / 3890
# code : 156464, page : 3523 / 3890
# code : 156464, page : 3524 / 3890
# code : 156464, page : 3525 / 3890
# code : 156464, page : 3526 / 3890
# code : 156464, page : 3527 / 3890
# code : 156464, page : 3528 / 3890
# code : 156464, page : 3529 / 3890
# code : 156464, page : 3530 / 3890
# code : 156464, page : 3531 / 3890
# code : 156464, page : 3532 / 3890
# code : 156464, page : 3533 / 3890
# code : 156464, page : 3534 / 3890
# code : 156464, page : 3535 / 3890
# code : 156464, page : 3536 / 3890
# code : 156464, page : 3537 / 3890
# code : 156464, page : 3538 / 3890
# code : 156464, page : 3539 / 3890
# code : 156464, page : 3540 / 3890
# code : 156464, page : 3541 / 3890
# code : 156464, page : 3542 / 3890
# code : 156464, page : 3543 / 3890
# code : 156464, page : 3544 / 3890
# code : 156464, page : 3545 / 3890
# code : 156464, page : 3546 / 3890
# code : 156464, page : 3547 / 3890
# code : 156464, page : 3548 / 3890
# code : 156464, page : 3549 / 3890
# code : 156464, page : 3550 / 3890
# code : 156464, page : 3551 / 3890
# code : 156464, page : 3552 / 3890
# code : 156464, page : 3553 / 3890
# code : 156464, page : 3554 / 3890
# code : 156464, page : 3555 / 3890
# code : 156464, page : 3556 / 3890
# code : 156464, page : 3557 / 3890
# code : 156464, page : 3558 / 3890
# code : 156464, page : 3559 / 3890
# code : 156464, page : 3560 / 3890
# code : 156464, page : 3561 / 3890
# code : 156464, page : 3562 / 3890
# code : 156464, page : 3563 / 3890
# code : 156464, page : 3564 / 3890
# code : 156464, page : 3565 / 3890
# code : 156464, page : 3566 / 3890
# code : 156464, page : 3567 / 3890
# code : 156464, page : 3568 / 3890
# code : 156464, page : 3569 / 3890
# code : 156464, page : 3570 / 3890
# code : 156464, page : 3571 / 3890
# code : 156464, page : 3572 / 3890
# code : 156464, page : 3573 / 3890
# code : 156464, page : 3574 / 3890
# code : 156464, page : 3575 / 3890
# code : 156464, page : 3576 / 3890
# code : 156464, page : 3577 / 3890
# code : 156464, page : 3578 / 3890
# code : 156464, page : 3579 / 3890
# code : 156464, page : 3580 / 3890
# code : 156464, page : 3581 / 3890
# code : 156464, page : 3582 / 3890
# code : 156464, page : 3583 / 3890
# code : 156464, page : 3584 / 3890
# code : 156464, page : 3585 / 3890
# code : 156464, page : 3586 / 3890
# code : 156464, page : 3587 / 3890
# code : 156464, page : 3588 / 3890
# code : 156464, page : 3589 / 3890
# code : 156464, page : 3590 / 3890
# code : 156464, page : 3591 / 3890
# code : 156464, page : 3592 / 3890
# code : 156464, page : 3593 / 3890
# code : 156464, page : 3594 / 3890
# code : 156464, page : 3595 / 3890
# code : 156464, page : 3596 / 3890
# code : 156464, page : 3597 / 3890
# code : 156464, page : 3598 / 3890
# code : 156464, page : 3599 / 3890
# code : 156464, page : 3600 / 3890
# code : 156464, page : 3601 / 3890
# code : 156464, page : 3602 / 3890
# code : 156464, page : 3603 / 3890
# code : 156464, page : 3604 / 3890
# code : 156464, page : 3605 / 3890
# code : 156464, page : 3606 / 3890
# code : 156464, page : 3607 / 3890
# code : 156464, page : 3608 / 3890
# code : 156464, page : 3609 / 3890
# code : 156464, page : 3610 / 3890
# code : 156464, page : 3611 / 3890
# code : 156464, page : 3612 / 3890
# code : 156464, page : 3613 / 3890
# code : 156464, page : 3614 / 3890
# code : 156464, page : 3615 / 3890
# code : 156464, page : 3616 / 3890
# code : 156464, page : 3617 / 3890
# code : 156464, page : 3618 / 3890
# code : 156464, page : 3619 / 3890
# code : 156464, page : 3620 / 3890
# code : 156464, page : 3621 / 3890
# code : 156464, page : 3622 / 3890
# code : 156464, page : 3623 / 3890
# code : 156464, page : 3624 / 3890
# code : 156464, page : 3625 / 3890
# code : 156464, page : 3626 / 3890
# code : 156464, page : 3627 / 3890
# code : 156464, page : 3628 / 3890
# code : 156464, page : 3629 / 3890
# code : 156464, page : 3630 / 3890
# code : 156464, page : 3631 / 3890
# code : 156464, page : 3632 / 3890
# code : 156464, page : 3633 / 3890
# code : 156464, page : 3634 / 3890
# code : 156464, page : 3635 / 3890
# code : 156464, page : 3636 / 3890
# code : 156464, page : 3637 / 3890
# code : 156464, page : 3638 / 3890
# code : 156464, page : 3639 / 3890
# code : 156464, page : 3640 / 3890
# code : 156464, page : 3641 / 3890
# code : 156464, page : 3642 / 3890
# code : 156464, page : 3643 / 3890
# code : 156464, page : 3644 / 3890
# code : 156464, page : 3645 / 3890
# code : 156464, page : 3646 / 3890
# code : 156464, page : 3647 / 3890
# code : 156464, page : 3648 / 3890
# code : 156464, page : 3649 / 3890
# code : 156464, page : 3650 / 3890
# code : 156464, page : 3651 / 3890
# code : 156464, page : 3652 / 3890
# code : 156464, page : 3653 / 3890
# code : 156464, page : 3654 / 3890
# code : 156464, page : 3655 / 3890
# code : 156464, page : 3656 / 3890
# code : 156464, page : 3657 / 3890
# code : 156464, page : 3658 / 3890
# code : 156464, page : 3659 / 3890
# code : 156464, page : 3660 / 3890
# code : 156464, page : 3661 / 3890
# code : 156464, page : 3662 / 3890
# code : 156464, page : 3663 / 3890
# code : 156464, page : 3664 / 3890
# code : 156464, page : 3665 / 3890
# code : 156464, page : 3666 / 3890
# code : 156464, page : 3667 / 3890
# code : 156464, page : 3668 / 3890
# code : 156464, page : 3669 / 3890
# code : 156464, page : 3670 / 3890
# code : 156464, page : 3671 / 3890
# code : 156464, page : 3672 / 3890
# code : 156464, page : 3673 / 3890
# code : 156464, page : 3674 / 3890
# code : 156464, page : 3675 / 3890
# code : 156464, page : 3676 / 3890
# code : 156464, page : 3677 / 3890
# code : 156464, page : 3678 / 3890
# code : 156464, page : 3679 / 3890
# code : 156464, page : 3680 / 3890
# code : 156464, page : 3681 / 3890
# code : 156464, page : 3682 / 3890
# code : 156464, page : 3683 / 3890
# code : 156464, page : 3684 / 3890
# code : 156464, page : 3685 / 3890
# code : 156464, page : 3686 / 3890
# code : 156464, page : 3687 / 3890
# code : 156464, page : 3688 / 3890
# code : 156464, page : 3689 / 3890
# code : 156464, page : 3690 / 3890
# code : 156464, page : 3691 / 3890
# code : 156464, page : 3692 / 3890
# code : 156464, page : 3693 / 3890
# code : 156464, page : 3694 / 3890
# code : 156464, page : 3695 / 3890
# code : 156464, page : 3696 / 3890
# code : 156464, page : 3697 / 3890
# code : 156464, page : 3698 / 3890
# code : 156464, page : 3699 / 3890
# code : 156464, page : 3700 / 3890
# code : 156464, page : 3701 / 3890
# code : 156464, page : 3702 / 3890
# code : 156464, page : 3703 / 3890
# code : 156464, page : 3704 / 3890
# code : 156464, page : 3705 / 3890
# code : 156464, page : 3706 / 3890
# code : 156464, page : 3707 / 3890
# code : 156464, page : 3708 / 3890
# code : 156464, page : 3709 / 3890
# code : 156464, page : 3710 / 3890
# code : 156464, page : 3711 / 3890
# code : 156464, page : 3712 / 3890
# code : 156464, page : 3713 / 3890
# code : 156464, page : 3714 / 3890
# code : 156464, page : 3715 / 3890
# code : 156464, page : 3716 / 3890
# code : 156464, page : 3717 / 3890
# code : 156464, page : 3718 / 3890
# code : 156464, page : 3719 / 3890
# code : 156464, page : 3720 / 3890
# code : 156464, page : 3721 / 3890
# code : 156464, page : 3722 / 3890
# code : 156464, page : 3723 / 3890
# code : 156464, page : 3724 / 3890
# code : 156464, page : 3725 / 3890
# code : 156464, page : 3726 / 3890
# code : 156464, page : 3727 / 3890
# code : 156464, page : 3728 / 3890
# code : 156464, page : 3729 / 3890
# code : 156464, page : 3730 / 3890
# code : 156464, page : 3731 / 3890
# code : 156464, page : 3732 / 3890
# code : 156464, page : 3733 / 3890
# code : 156464, page : 3734 / 3890
# code : 156464, page : 3735 / 3890
# code : 156464, page : 3736 / 3890
# code : 156464, page : 3737 / 3890
# code : 156464, page : 3738 / 3890
# code : 156464, page : 3739 / 3890
# code : 156464, page : 3740 / 3890
# code : 156464, page : 3741 / 3890
# code : 156464, page : 3742 / 3890
# code : 156464, page : 3743 / 3890
# code : 156464, page : 3744 / 3890
# code : 156464, page : 3745 / 3890
# code : 156464, page : 3746 / 3890
# code : 156464, page : 3747 / 3890
# code : 156464, page : 3748 / 3890
# code : 156464, page : 3749 / 3890
# code : 156464, page : 3750 / 3890
# code : 156464, page : 3751 / 3890
# code : 156464, page : 3752 / 3890
# code : 156464, page : 3753 / 3890
# code : 156464, page : 3754 / 3890
# code : 156464, page : 3755 / 3890
# code : 156464, page : 3756 / 3890
# code : 156464, page : 3757 / 3890
# code : 156464, page : 3758 / 3890
# code : 156464, page : 3759 / 3890
# code : 156464, page : 3760 / 3890
# code : 156464, page : 3761 / 3890
# code : 156464, page : 3762 / 3890
# code : 156464, page : 3763 / 3890
# code : 156464, page : 3764 / 3890
# code : 156464, page : 3765 / 3890
# code : 156464, page : 3766 / 3890
# code : 156464, page : 3767 / 3890
# code : 156464, page : 3768 / 3890
# code : 156464, page : 3769 / 3890
# code : 156464, page : 3770 / 3890
# code : 156464, page : 3771 / 3890
# code : 156464, page : 3772 / 3890
# code : 156464, page : 3773 / 3890
# code : 156464, page : 3774 / 3890
# code : 156464, page : 3775 / 3890
# code : 156464, page : 3776 / 3890
# code : 156464, page : 3777 / 3890
# code : 156464, page : 3778 / 3890
# code : 156464, page : 3779 / 3890
# code : 156464, page : 3780 / 3890
# code : 156464, page : 3781 / 3890
# code : 156464, page : 3782 / 3890
# code : 156464, page : 3783 / 3890
# code : 156464, page : 3784 / 3890
# code : 156464, page : 3785 / 3890
# code : 156464, page : 3786 / 3890
# code : 156464, page : 3787 / 3890
# code : 156464, page : 3788 / 3890
# code : 156464, page : 3789 / 3890
# code : 156464, page : 3790 / 3890
# code : 156464, page : 3791 / 3890
# code : 156464, page : 3792 / 3890
# code : 156464, page : 3793 / 3890
# code : 156464, page : 3794 / 3890
# code : 156464, page : 3795 / 3890
# code : 156464, page : 3796 / 3890
# code : 156464, page : 3797 / 3890
# code : 156464, page : 3798 / 3890
# code : 156464, page : 3799 / 3890
# code : 156464, page : 3800 / 3890
# code : 156464, page : 3801 / 3890
# code : 156464, page : 3802 / 3890
# code : 156464, page : 3803 / 3890
# code : 156464, page : 3804 / 3890
# code : 156464, page : 3805 / 3890
# code : 156464, page : 3806 / 3890
# code : 156464, page : 3807 / 3890
# code : 156464, page : 3808 / 3890
# code : 156464, page : 3809 / 3890
# code : 156464, page : 3810 / 3890
# code : 156464, page : 3811 / 3890
# code : 156464, page : 3812 / 3890
# code : 156464, page : 3813 / 3890
# code : 156464, page : 3814 / 3890
# code : 156464, page : 3815 / 3890
# code : 156464, page : 3816 / 3890
# code : 156464, page : 3817 / 3890
# code : 156464, page : 3818 / 3890
# code : 156464, page : 3819 / 3890
# code : 156464, page : 3820 / 3890
# code : 156464, page : 3821 / 3890
# code : 156464, page : 3822 / 3890
# code : 156464, page : 3823 / 3890
# code : 156464, page : 3824 / 3890
# code : 156464, page : 3825 / 3890
# code : 156464, page : 3826 / 3890
# code : 156464, page : 3827 / 3890
# code : 156464, page : 3828 / 3890
# code : 156464, page : 3829 / 3890
# code : 156464, page : 3830 / 3890
# code : 156464, page : 3831 / 3890
# code : 156464, page : 3832 / 3890
# code : 156464, page : 3833 / 3890
# code : 156464, page : 3834 / 3890
# code : 156464, page : 3835 / 3890
# code : 156464, page : 3836 / 3890
# code : 156464, page : 3837 / 3890
# code : 156464, page : 3838 / 3890
# code : 156464, page : 3839 / 3890
# code : 156464, page : 3840 / 3890
# code : 156464, page : 3841 / 3890
# code : 156464, page : 3842 / 3890
# code : 156464, page : 3843 / 3890
# code : 156464, page : 3844 / 3890
# code : 156464, page : 3845 / 3890
# code : 156464, page : 3846 / 3890
# code : 156464, page : 3847 / 3890
# code : 156464, page : 3848 / 3890
# code : 156464, page : 3849 / 3890
# code : 156464, page : 3850 / 3890
# code : 156464, page : 3851 / 3890
# code : 156464, page : 3852 / 3890
# code : 156464, page : 3853 / 3890
# code : 156464, page : 3854 / 3890
# code : 156464, page : 3855 / 3890
# code : 156464, page : 3856 / 3890
# code : 156464, page : 3857 / 3890
# code : 156464, page : 3858 / 3890
# code : 156464, page : 3859 / 3890
# code : 156464, page : 3860 / 3890
# code : 156464, page : 3861 / 3890
# code : 156464, page : 3862 / 3890
# code : 156464, page : 3863 / 3890
# code : 156464, page : 3864 / 3890
# code : 156464, page : 3865 / 3890
# code : 156464, page : 3866 / 3890
# code : 156464, page : 3867 / 3890
# code : 156464, page : 3868 / 3890
# code : 156464, page : 3869 / 3890
# code : 156464, page : 3870 / 3890
# code : 156464, page : 3871 / 3890
# code : 156464, page : 3872 / 3890
# code : 156464, page : 3873 / 3890
# code : 156464, page : 3874 / 3890
# code : 156464, page : 3875 / 3890
# code : 156464, page : 3876 / 3890
# code : 156464, page : 3877 / 3890
# code : 156464, page : 3878 / 3890
# code : 156464, page : 3879 / 3890
# code : 156464, page : 3880 / 3890
# code : 156464, page : 3881 / 3890
# code : 156464, page : 3882 / 3890
# code : 156464, page : 3883 / 3890
# code : 156464, page : 3884 / 3890
# code : 156464, page : 3885 / 3890
# code : 156464, page : 3886 / 3890
# code : 156464, page : 3887 / 3890
# code : 156464, page : 3888 / 3890
# code : 156464, page : 3889 / 3890
# code : 156464, page : 3890 / 3890
# 수집 완료

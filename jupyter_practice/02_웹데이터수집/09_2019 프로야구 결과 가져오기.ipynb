# %%
from selenium import webdriver
import time
import pandas as pd

# %%
# 데이터를 저장할 딕셔너리
data_dict = {
    'date' : [],
    'team1_name' : [],
    'team2_name' : [],
    'team1_score' : [],
    'team2_score' : []
}

# 웹 드라이버 로딩
driver = webdriver.Chrome()

# %%
# 페이지 요청
driver.get('https://sports.news.naver.com/kbaseball/schedule/index.nhn')

# %% [markdown]
# ### 날짜를 입력받아 해당 날짜의 데이터를 추출한다.

# %%
def getData(script_code):
    # 스크립트를 실행시켜 원하는 날짜가 나오도록 한다.
    driver.execute_script(script_code)
    time.sleep(1)
    # 스케줄 표 전체를 가져온다.
    sch_score_tag = driver.find_element_by_css_selector('#sch_recent_scoreboard > div > div')
    
    # 해당 날짜에 경기가 있는지 확인
    temp_tag = sch_score_tag.find_elements_by_css_selector('.banner_mon')
    # 스크립트 코드에서 날짜만 추출한다.
    date_str = script_code.split("'")[1]
    # 경기가 없다면 ...
    if len(temp_tag) > 0:
        print(f'{date_str} : 경기 없음')
    else:
        print(f'{date_str} : 경기 있음')
        li_list = driver.find_elements_by_css_selector('#todaySchedule > li.end')
        for li_tag in li_list:
            # 팀명
            team1_name_tag = li_tag.find_element_by_css_selector('div.vs_lft > p > strong')
            team2_name_tag = li_tag.find_element_by_css_selector('div.vs_rgt > p > strong')
            
            # 점수
            team1_score_tag = li_tag.find_element_by_css_selector('div.vs_lft > strong')
            team2_score_tag = li_tag.find_element_by_css_selector('div.vs_rgt > strong')
            
            team1_name = team1_name_tag.text.strip()
            team2_name = team2_name_tag.text.strip()
            team1_score = team1_score_tag.text.strip()
            team2_score = team2_score_tag.text.strip()
            
#             print(f'{team1_name} {team1_score} : {team2_score} {team2_name}')
            
            data_dict['date'].append(date_str)
            data_dict['team1_name'].append(team1_name)
            data_dict['team2_name'].append(team2_name)
            data_dict['team1_score'].append(team1_score)
            data_dict['team2_score'].append(team2_score)

# %%
def getWeekData():
    ul_tag = driver.find_element_by_css_selector('#sch_recent_scoreboard > div > div > ul')
    li_list = ul_tag.find_elements_by_css_selector('li')
    
    date_list = []
    
    # 주중 일정을 보기 위한 스크립트 코드 추출
    for li_tag in li_list[1:-1]: # 월~일만
        a_tag = li_tag.find_element_by_css_selector('a')
        script_code = a_tag.get_attribute('onclick')
        script_code = script_code.split(':')[1]
        
        date_list.append(script_code)
        
    # 다음 주 첫번째 날짜를 보기 위한 스크립트 코드 추출
    a_tag = li_list[-1].find_element_by_css_selector('a')
    script_code = a_tag.get_attribute('onclick')
    script_code = script_code.split(':')[1]
    
    return date_list, script_code

# %%
# getData('20190311')
driver.execute_script("scoreBoardInstance.setScoreBoard('20190311')")
time.sleep(1)

while True:
    date_list, next_week = getWeekData()

    for script_code in date_list:
        getData(script_code)
    if date_list[-1].find('20191027') == -1:
#     if date_list[-1].find('20190331') == -1:
        driver.execute_script(next_week)
        time.sleep(1)
    else:
        break

# 저장
df1 = pd.DataFrame.from_dict(data_dict)
df1.to_csv('baseball.csv', encoding='utf-8-sig', index=False)

print('수집완료')
# Out:
# 20190311 : 경기 없음
# 20190312 : 경기 있음
# 20190313 : 경기 있음
# 20190314 : 경기 있음
# 20190315 : 경기 있음
# 20190316 : 경기 있음
# 20190317 : 경기 있음
# 20190318 : 경기 없음
# 20190319 : 경기 있음
# 20190320 : 경기 있음
# 20190321 : 경기 없음
# 20190322 : 경기 없음
# 20190323 : 경기 있음
# 20190324 : 경기 있음
# 20190325 : 경기 없음
# 20190326 : 경기 있음
# 20190327 : 경기 있음
# 20190328 : 경기 있음
# 20190329 : 경기 있음
# 20190330 : 경기 있음
# 20190331 : 경기 있음
# 20190401 : 경기 없음
# 20190402 : 경기 있음
# 20190403 : 경기 있음
# 20190404 : 경기 있음
# 20190405 : 경기 있음
# 20190406 : 경기 있음
# 20190407 : 경기 있음
# 20190408 : 경기 없음
# 20190409 : 경기 있음
# 20190410 : 경기 있음
# 20190411 : 경기 있음
# 20190412 : 경기 있음
# 20190413 : 경기 있음
# 20190414 : 경기 있음
# 20190415 : 경기 없음
# 20190416 : 경기 있음
# 20190417 : 경기 있음
# 20190418 : 경기 있음
# 20190419 : 경기 있음
# 20190420 : 경기 있음
# 20190421 : 경기 있음
# 20190422 : 경기 없음
# 20190423 : 경기 있음
# 20190424 : 경기 있음
# 20190425 : 경기 있음
# 20190426 : 경기 있음
# 20190427 : 경기 있음
# 20190428 : 경기 있음
# 20190429 : 경기 없음
# 20190430 : 경기 있음
# 20190501 : 경기 있음
# 20190502 : 경기 있음
# 20190503 : 경기 있음
# 20190504 : 경기 있음
# 20190505 : 경기 있음
# 20190506 : 경기 없음
# 20190507 : 경기 있음
# 20190508 : 경기 있음
# 20190509 : 경기 있음
# 20190510 : 경기 있음
# 20190511 : 경기 있음
# 20190512 : 경기 있음
# 20190513 : 경기 없음
# 20190514 : 경기 있음
# 20190515 : 경기 있음
# 20190516 : 경기 있음
# 20190517 : 경기 있음
# 20190518 : 경기 있음
# 20190519 : 경기 있음
# 20190520 : 경기 없음
# 20190521 : 경기 있음
# 20190522 : 경기 있음
# 20190523 : 경기 있음
# 20190524 : 경기 있음
# 20190525 : 경기 있음
# 20190526 : 경기 있음
# 20190527 : 경기 없음
# 20190528 : 경기 있음
# 20190529 : 경기 있음
# 20190530 : 경기 있음
# 20190531 : 경기 있음
# 20190601 : 경기 있음
# 20190602 : 경기 있음
# 20190603 : 경기 없음
# 20190604 : 경기 있음
# 20190605 : 경기 있음
# 20190606 : 경기 있음
# 20190607 : 경기 있음
# 20190608 : 경기 있음
# 20190609 : 경기 있음
# 20190610 : 경기 없음
# 20190611 : 경기 있음
# 20190612 : 경기 있음
# 20190613 : 경기 있음
# 20190614 : 경기 있음
# 20190615 : 경기 있음
# 20190616 : 경기 있음
# 20190617 : 경기 없음
# 20190618 : 경기 있음
# 20190619 : 경기 있음
# 20190620 : 경기 있음
# 20190621 : 경기 있음
# 20190622 : 경기 있음
# 20190623 : 경기 있음
# 20190624 : 경기 없음
# 20190625 : 경기 있음
# 20190626 : 경기 있음
# 20190627 : 경기 있음
# 20190628 : 경기 있음
# 20190629 : 경기 있음
# 20190630 : 경기 있음
# 20190701 : 경기 없음
# 20190702 : 경기 있음
# 20190703 : 경기 있음
# 20190704 : 경기 있음
# 20190705 : 경기 있음
# 20190706 : 경기 있음
# 20190707 : 경기 있음
# 20190708 : 경기 없음
# 20190709 : 경기 있음
# 20190710 : 경기 있음
# 20190711 : 경기 있음
# 20190712 : 경기 있음
# 20190713 : 경기 있음
# 20190714 : 경기 있음
# 20190715 : 경기 없음
# 20190716 : 경기 있음
# 20190717 : 경기 있음
# 20190718 : 경기 있음
# 20190719 : 경기 없음
# 20190720 : 경기 있음
# 20190721 : 경기 있음
# 20190722 : 경기 없음
# 20190723 : 경기 없음
# 20190724 : 경기 없음
# 20190725 : 경기 없음
# 20190726 : 경기 있음
# 20190727 : 경기 있음
# 20190728 : 경기 있음
# 20190729 : 경기 없음
# 20190730 : 경기 있음
# 20190731 : 경기 있음
# 20190801 : 경기 있음
# 20190802 : 경기 없음
# 20190803 : 경기 있음
# 20190804 : 경기 있음
# 20190805 : 경기 없음
# 20190806 : 경기 있음
# 20190807 : 경기 있음
# 20190808 : 경기 있음
# 20190809 : 경기 있음
# 20190810 : 경기 있음
# 20190811 : 경기 있음
# 20190812 : 경기 없음
# 20190813 : 경기 있음
# 20190814 : 경기 있음
# 20190815 : 경기 있음
# 20190816 : 경기 있음
# 20190817 : 경기 있음
# 20190818 : 경기 있음
# 20190819 : 경기 없음
# 20190820 : 경기 있음
# 20190821 : 경기 있음
# 20190822 : 경기 있음
# 20190823 : 경기 있음
# 20190824 : 경기 있음
# 20190825 : 경기 있음
# 20190826 : 경기 없음
# 20190827 : 경기 있음
# 20190828 : 경기 있음
# 20190829 : 경기 있음
# 20190830 : 경기 있음
# 20190831 : 경기 있음
# 20190901 : 경기 있음
# 20190902 : 경기 없음
# 20190903 : 경기 있음
# 20190904 : 경기 있음
# 20190905 : 경기 있음
# 20190906 : 경기 있음
# 20190907 : 경기 있음
# 20190908 : 경기 있음
# 20190909 : 경기 없음
# 20190910 : 경기 있음
# 20190911 : 경기 있음
# 20190912 : 경기 있음
# 20190913 : 경기 있음
# 20190914 : 경기 있음
# 20190915 : 경기 있음
# 20190916 : 경기 있음
# 20190917 : 경기 있음
# 20190918 : 경기 있음
# 20190919 : 경기 있음
# 20190920 : 경기 있음
# 20190921 : 경기 있음
# 20190922 : 경기 있음
# 20190923 : 경기 있음
# 20190924 : 경기 있음
# 20190925 : 경기 있음
# 20190926 : 경기 있음
# 20190927 : 경기 있음
# 20190928 : 경기 있음
# 20190929 : 경기 있음
# 20190930 : 경기 있음
# 20191001 : 경기 있음
# 20191002 : 경기 없음
# 20191003 : 경기 있음
# 20191004 : 경기 없음
# 20191005 : 경기 없음
# 20191006 : 경기 있음
# 20191007 : 경기 있음
# 20191008 : 경기 없음
# 20191009 : 경기 있음
# 20191010 : 경기 있음
# 20191011 : 경기 없음
# 20191012 : 경기 없음
# 20191013 : 경기 없음
# 20191014 : 경기 있음
# 20191015 : 경기 있음
# 20191016 : 경기 없음
# 20191017 : 경기 있음
# 20191018 : 경기 없음
# 20191019 : 경기 없음
# 20191020 : 경기 없음
# 20191021 : 경기 없음
# 20191022 : 경기 있음
# 20191023 : 경기 있음
# 20191024 : 경기 없음
# 20191025 : 경기 있음
# 20191026 : 경기 있음
# 20191027 : 경기 없음
# 수집완료

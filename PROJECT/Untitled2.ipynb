# %%
import pandas as pd

# %%
df1 = pd.read_csv('geometry.csv')
df1.head(2)
# Out:
#                                             GEOMETRY
# 0  POLYGON ((203517.4289147551 548480.9238001491,...
# 1  POLYGON ((204518.2787147551 545594.5939001491,...

# %%
str1 = df1.GEOMETRY[6]
str2 = str1[10:-2]
list1 = str2.split(' ')
len(list1)/2
# Out:
# 273.0

# %%
def func1(df1, n):
    str1 = df1.GEOMETRY[n]
    str2 = str1[10:-2]
    list1 = str2.split(' ')
    return print(len(list1)//2)

# %%
for i in range(100):
    func1(df1, i)
# Out:
# 691
# 220
# 115
# 117
# 28699
# 51
# 273
# 446
# 471
# 526
# 229
# 239
# 162
# 467
# 382
# 193
# 200
# 661
# 1719
# 149
# 276
# 732
# 126
# 435
# 3376
# 245
# 403
# 3223
# 209
# 683
# 646
# 159
# 3238
# 116
# 148
# 384
# 827
# 1292
# 1476
# 216
# 372
# 791
# 1408
# 237
# 766
# 372
# 1886
# 215
# 122
# 103
# 252
# 61
# 249
# 602
# 1336
# 693
# 405
# 574
# 221
# 454
# 309
# 330
# 313
# 715
# 894
# 550
# 1709
# 986
# 237
# 287
# 812
# 231
# 1825
# 1509
# 1543
# 372
# 540
# 829
# 5
# 194
# 189
# 288
# 282
# 398
# 889
# 51
# 115
# 115
# 16
# 16
# 27
# 27
# 193
# 193
# 19
# 19
# 48
# 48
# 52
# 52

# %%
df1.GEOMETRY[80]
# Out:
# 'POLYGON ((209263.8336147551 541806.3471001491, 209262.4061147551 541801.7191001491, 209261.7486147551 541799.5189001492, 209260.9962147551 541797.131900149, 209260.1656147551 541794.6709001492, 209259.2724147551 541792.2505001491, 209258.3897147551 541790.107300149, 209257.4991147551 541788.1917001491, 209256.6286147551 541786.5701001491, 209255.4987147551 541784.7505001491, 209254.1679147551 541782.8883001491, 209253.1751147551 541781.7137001491, 209251.6532147551 541780.2710001491, 209249.6768147551 541778.9831001491, 209247.6204147551 541778.3845001491, 209244.9868147551 541778.7289001491, 209242.9692147551 541779.5102001491, 209240.2216147551 541780.8439001491, 209238.8250147551 541781.4843001491, 209236.7803147551 541782.2034001491, 209234.2748147551 541782.6288001491, 209231.9573147551 541782.4118001491, 209230.0648147551 541781.5358001491, 209228.6871147551 541780.2259001491, 209227.8879147551 541779.0221001491, 209227.1952147551 541777.6973001491, 209225.9248147551 541774.94
# ...

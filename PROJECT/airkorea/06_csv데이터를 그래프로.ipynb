# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import rcParams
import numpy as np

# %%
plt.rc('font', family='Malgun Gothic')

# %%
def read_csv(station_name):
    yearList = ['2016','2017','2018','2019','2020']
    for year in yearList: 
        if year != '2020':
            for month in range(1,13):
                df1 = pd.read_csv(f'{station_name}/{year}/{station_name}_{year}_{month}.csv')
        else:
            df1 = pd.read_csv(f'{station_name}/{year}/{station_name}_2020_1.csv')

# %%
def read_csv_only_one(station_name, year, month):
    if year != '2020':
        df1 = pd.read_csv(f'{station_name}/{year}/{station_name}_{year}_{month}.csv')
    else:
        df1 = pd.read_csv(f'{station_name}/{year}/{station_name}_2020_1.csv')
    return df1

# %%
# read_csv('Gangnam_Hakdongro')
df1 = read_csv_only_one('Gangnam_Hakdongro','2019','5')
df2 = read_csv_only_one('Gangnam_Dosandaero','2019','5')
df3 = read_csv_only_one('Gangdong_Gucheonmeonro','2019','5')

# %%
df1
# Out:
#               time   pm10  pm2.5
# 0    2019-05-01:01   21.0   12.0
# 1    2019-05-01:02   21.0   14.0
# 2    2019-05-01:03   22.0   13.0
# 3    2019-05-01:04   22.0   16.0
# 4    2019-05-01:05   25.0   20.0
# 5    2019-05-01:06   25.0   20.0
# 6    2019-05-01:07   24.0   16.0
# 7    2019-05-01:08   22.0   17.0
# 8    2019-05-01:09   25.0   20.0
# 9    2019-05-01:10   24.0   17.0
# 10   2019-05-01:11   31.0   19.0
# 11   2019-05-01:12   54.0   33.0
# 12   2019-05-01:13   56.0   34.0
# 13   2019-05-01:14   48.0   28.0
# 14   2019-05-01:15   50.0   27.0
# 15   2019-05-01:16   56.0   33.0
# 16   2019-05-01:17   62.0   34.0
# 17   2019-05-01:18   58.0   32.0
# 18   2019-05-01:19   76.0   33.0
# 19   2019-05-01:20   91.0   32.0
# 20   2019-05-01:21  102.0   30.0
# 21   2019-05-01:22  102.0   28.0
# 22   2019-05-01:23   91.0   22.0
# 23   2019-05-01:24   87.0   19.0
# 24   2019-05-02:01   83.0   21.0
# 25   2019-05-02:02   79.0   20.0
# 26   2019-05-02:03   75.0   16.0
# 27   2019-05-02:04   73.0   19.0
# 28   2019-05-02:05   69.0   18.0
# 29   2019-05-02:06   66.0   19.0
# ..             ...    ...    ...
# 714  2019-05-30:19   44.0   29.0
# 715  2019-05-30:20   46.0   31.0
# 716  2019-05-30:21   41.0   26.0
# 717  2019-05-30:22   35.0   25.0
# 718  2019-05-30:23   25.0   13.0
# 719  2019-05-30:24   17.0   10.0
# 720  2019-05-31:01   11.0    8.0
# 721  2019-05-31:02   11.0    7.0
# 722  2019-05-31:03   11.0    6.0
# 723  2019-05-31:04   12.0    9.0
# 724  2019-05-31:05   15.0   10.0
# 725  2019-05-31:06   12.0    9.0
# 726  2019-05-31:07   11.0    6.0
# 727  2019-05-31:08   11.0    7.0
# 728  2019-05-31:09   11.0    8.0
# 729  2019-05-31:10   15.0    6.0
# 730  2019-05-31:11   15.0    9.0
# 731  2019-05-31:12   13.0    7.0
# 732  2019-05-31:13   13.0    5.0
# 733  2019-05-31:14   13.0    9.0
# 734  2019-05-31:15   16.0   10.0
# 735  2019-05-31:16   18.0    9.0
# 736  2019-05-31:17   21.0   12.0
# 737  2019-05-31:18   19.0   11.0
# 738  2019-05-31:19   20.0   11.0
# 739  2019-05-31:20   19.0   11.0
# 740  2019-05-31:21   14.0   10.0
# 741  2019-05-31:22   15.0   10.0
# 742  2019-05-31:23   14.0    9.0
# 743  2019-05-31:24   14.0    9.0
#
# [744 rows x 3 columns]

# %%
df2
# Out:
#               time   pm10  pm2.5
# 0    2019-05-01:01   36.0   21.0
# 1    2019-05-01:02   30.0   21.0
# 2    2019-05-01:03   29.0   18.0
# 3    2019-05-01:04   31.0   20.0
# 4    2019-05-01:05   37.0   28.0
# 5    2019-05-01:06   43.0   30.0
# 6    2019-05-01:07   41.0   27.0
# 7    2019-05-01:08   43.0   30.0
# 8    2019-05-01:09   47.0   31.0
# 9    2019-05-01:10   58.0   37.0
# 10   2019-05-01:11   70.0   40.0
# 11   2019-05-01:12   92.0   55.0
# 12   2019-05-01:13   69.0   39.0
# 13   2019-05-01:14   68.0   31.0
# 14   2019-05-01:15   77.0   40.0
# 15   2019-05-01:16   88.0   48.0
# 16   2019-05-01:17   87.0   46.0
# 17   2019-05-01:18   93.0   41.0
# 18   2019-05-01:19  110.0   40.0
# 19   2019-05-01:20  131.0   41.0
# 20   2019-05-01:21  142.0   35.0
# 21   2019-05-01:22  129.0   29.0
# 22   2019-05-01:23  113.0   25.0
# 23   2019-05-01:24  105.0   20.0
# 24   2019-05-02:01  107.0   24.0
# 25   2019-05-02:02   98.0   26.0
# 26   2019-05-02:03  102.0   21.0
# 27   2019-05-02:04   87.0   21.0
# 28   2019-05-02:05   78.0   22.0
# 29   2019-05-02:06   83.0   20.0
# ..             ...    ...    ...
# 714  2019-05-30:19   73.0   37.0
# 715  2019-05-30:20   77.0   44.0
# 716  2019-05-30:21   62.0   32.0
# 717  2019-05-30:22   55.0   27.0
# 718  2019-05-30:23   32.0   17.0
# 719  2019-05-30:24   23.0   15.0
# 720  2019-05-31:01   18.0   11.0
# 721  2019-05-31:02   17.0   10.0
# 722  2019-05-31:03   16.0   10.0
# 723  2019-05-31:04   18.0   12.0
# 724  2019-05-31:05   26.0   10.0
# 725  2019-05-31:06   22.0   16.0
# 726  2019-05-31:07   17.0   11.0
# 727  2019-05-31:08   25.0   14.0
# 728  2019-05-31:09   30.0   17.0
# 729  2019-05-31:10   35.0   15.0
# 730  2019-05-31:11   26.0   15.0
# 731  2019-05-31:12   27.0   16.0
# 732  2019-05-31:13   29.0   11.0
# 733  2019-05-31:14   25.0    9.0
# 734  2019-05-31:15   29.0   12.0
# 735  2019-05-31:16   27.0   16.0
# 736  2019-05-31:17   37.0   18.0
# 737  2019-05-31:18   30.0   13.0
# 738  2019-05-31:19   26.0   16.0
# 739  2019-05-31:20   34.0   18.0
# 740  2019-05-31:21   28.0   14.0
# 741  2019-05-31:22   24.0   16.0
# 742  2019-05-31:23   28.0   22.0
# 743  2019-05-31:24   27.0   15.0
#
# [744 rows x 3 columns]

# %%
x=[_ for _ in range(744)]
time=[]
for i in df1['time']:
    time.append(i)
time_ticks=[]
for i in range(len(time)):
    if i%24 == 0:
        time_ticks.append(i)
ticks_convert=[]
for i in range(len(time)):
#     i = str(i+1) + '일'
    ticks_convert.append(i+1)
h_pm10=[]
h_pm2_5=[]
for i in df1['pm10']:
    h_pm10.append(i)
for i in df1['pm2.5']:
    h_pm2_5.append(i)

# %%
d_pm10=[]
d_pm2_5=[]
for i in df2['pm10']:
    d_pm10.append(i)
for i in df2['pm2.5']:
    d_pm2_5.append(i)

# %%
g_pm10=[]
g_pm2_5=[]
for i in df3['pm10']:
    g_pm10.append(i)
for i in df3['pm2.5']:
    g_pm2_5.append(i)

# %%
dnp_pm10 = np.array(d_pm10)
hnp_pm10 = np.array(h_pm10)
cha = dnp_pm10 - hnp_pm10

# %%
plt.figure(figsize=(12, 5))
# plt.plot(x, h_pm10, label='h_pm10')
# plt.plot(x, h_pm2_5, label='h_pm2.5')

# plt.plot(x, d_pm10, label='d_pm10')
# plt.plot(x, d_pm2_5, label='d_pm2.5')

# plt.plot(x, g_pm10, label='g_pm10')
plt.plot(x, cha)
plt.legend()
plt.xticks(time_ticks,ticks_convert)
plt.xlabel('일')
plt.ylabel('미세먼지 농도')
plt.show()
# Out:
# No handles with labels found to put in legend.
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)
